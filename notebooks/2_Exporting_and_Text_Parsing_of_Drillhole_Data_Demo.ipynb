# %% [markdown]
# ## Exporting and Text Parsing of Drillhole Data
# This notebook reads in from an export of the PostGIS/PostgreSQL WAMEX (Western Australian Mineral) database. A local subset copy instead of directly connecting to the database is used in this workshop. WAMEX contains mineral exploration reports and data that have lapsed the period of confidentiality. Online access is free of charge at:
# https://www.dmp.wa.gov.au/Geological-Survey/Mineral-exploration-Reports-1401.aspx
#
# From this database export, we pullout the following information: <br>
# 1 ) Collar (CollarID, Longitude, Latitude, RL, MaxDepth) <br>
# 2 ) Survey (CollarID, Depth, Azimuth, Dip) <br>
# 3 ) Lithology (CollarID, From_Depth, To_Depth, Company_LithoCode) <br>
#
# The Survey table is further processed to calculate downhole X,Y,Z using minimum curvature.
# The Lithology table is further processed to decode the Company LithoCodes into their respective lithologies. These lithologies are then standardized across different drilling campaigns and upscaled to be classified into broader rock types.

# %% [markdown]
# ## WAMEX Database
# Let's take a look at what the database information looks like and how these tables are related:
# <a href="./graphics/gswadh_schema.pdf">gswadh_schema.pdf</a>
# <img src='./graphics/gswadh_schema.bmp'>
# <br>
# Today, we will focus on tables necessary for collar, survey and lithology files.
# <img src='./graphics/postgres-database.png'>

# %%
#import os, sys

#print(os.getcwd())
#sys.path.append(os.getcwd())

# %%
#sys.path

# %%
import pandas as pd
from dh2loop import dh2l
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# %run -i "dh2l_config.py"
# Out:
# Default parameters loaded from dh2l_config.py:
#
#
# host_ = '130.95.198.59'
# port_= 5432
# DB_='gswa_dh'
# user_ = 'postgres'
# pwd_ = 'loopie123pgpw'
# #export_path = ''
#
#
# #File encoding type
# encoding_1 ="utf-8"
# encoding_2 = "ISO-8859-1"
#
# #Database Files
# data_path='../data/'
# wamex_path='../data/wamex/'
# collar_file=wamex_path+'collar.csv'
# collarattr_file=wamex_path+'collarattr.csv'
# dhsurvey_file=wamex_path+'dhsurvey.csv'
# dhsurveyattr_file=wamex_path+'dhsurveyattr.csv'
# dhgeology_file=wamex_path+'dhgeology.csv'
# dhgeologyattr_file=wamex_path+'dhgeologyattr.csv'
#
# #Thesauri
# rl_maxdepth_dic_file= wamex_path+'rl_maxdepth_dic.csv'
# survey_dic_file=wamex_path+'survey_dic.csv'
# dic_attr_col_lithology_file=wamex_path+'dic_att_col_lithology.csv'
# dic_attr_val_lithology_file=wamex_path+'dic_attr_val_lithology_filter.csv'
# cleanup_lithology_file=wamex_path+'cleanup_lithology.csv'
# litho_dic_file=wamex_path+'litho_dic_1.csv'
# CET_hierarchy_dico_file=wamex_path+'hierarchy_dico.csv'
#
# #ExportFiles
# export_path='../data/export/'
# DB_Collar_Export=export_path+'DB_Collar_Export.csv'
# DB_Survey_Export=export_path+'DB_Survey_Export.csv'
# DB_Survey_Export_Calc=export_path+'DB_Survey_Export_Calc.csv'
# CET_Litho=export_path+'CET_Litho.csv'
# DB_Lithology_Export=export_path+'DB_Lithology_Export.csv'
# DB_Lithology_Export_Backup=export_path+'DB_Lithology_Export_Backup.csv'
# DB_Lithology_Upscaled=export_path+'DB_Lithology_Upscaled.csv'
# DB_Lithology_Export_Calc=export_path+'DB_Lithology_Export_Calc.csv'
# DB_Lithology_Export_VTK=export_path+'DB_Lithology_Export.vtp'
#
#
# #Shapefiles
# shapefile_path='../data/shapefile/'
# geology=shapefile_path+'500K_interpgeol16_yalgoo_singleton.shp'
#
# #Projections
# src_crs = {'init': 'EPSG:4326'}  # coordinate reference system for imported dtms (geodetic lat/long WGS84)
# dst_crs = {'init': 'EPSG:28350'} # coordinate system for data
#
# print('Default parameters loaded from dh2l_config.py:')
# with open('../notebooks/dh2l_config.py', 'r') as myfile:
#   data = myfile.read()
#   print(data)
#   myfile.close()
# print('\nModify these parameters in the cell below')
#
# Modify these parameters in the cell below

# %% [markdown]
# ## Exporting Collar Data
#
# Let's take a look at <b>collar</b> and <b>collarattr</b> table:

# %%
collar= pd.read_csv(collar_file,encoding = encoding_2, dtype='object')
collar.head()
# Out:
#        id                    holeid anumber companyholeid       dataset  \
# 0  153802  69189Minjar NorthSSRC007   69189       SSRC007  Minjar North
# 1  153803  69189Minjar NorthSSRC008   69189       SSRC008  Minjar North
# 2  153804  69189Minjar NorthSSRC009   69189       SSRC009  Minjar North
# 3  153813  69189Minjar NorthSSRC019   69189       SSRC019  Minjar North
# 4  153816  69189Minjar NorthSSRC022   69189       SSRC022  Minjar North
#
#   companyid longitude  latitude istransformed modifieddate modifiedby  \
# 0      3049   116.949  -28.9058          True          NaN        NaN
# 1      3049   116.949  -28.9058          True          NaN        NaN
# 2      3049   116.949  -28.9058          True          NaN        NaN
# 3      3049   116.949  -28.9065          True          NaN        NaN
# 4      3049   116.949  -28.9068          True          NaN        NaN
#
#   mrtfileid holetype maxdepth  \
# 0      5252       RC      127
# 1      5252       RC      130
# 2      5252       RC      120
# 3      5252       RC      174
# 4      5252       RC      146
#
#                                                 geom
# 0  0101000020E610000000000000C33C5D4000000000E0E7...
# 1  0101000020E6100000000000C0C23C5D4000000020E0E7...
# 2  0101000020E610000000000000C23C5D4000000040E0E7...
# 3  0101000020E610000000000040C03C5D40000000E00FE8...
# 4  0101000020E610000000000080C23C5D400000004027E8...

# %%
collarattr= pd.read_csv(collarattr_file,encoding = encoding_2, dtype='object')
collarattr.loc[collarattr['collarid'] == '153802']
# Out:
#         id collarid   attributecolumn                     attributevalue  \
# 0  1769961   153802         Elevation                            359.251
# 1  1769962   153802                TD                                127
# 2  1769963   153802     Drilling_code                                 RC
# 3  1769964   153802          Tenement                            M59/421
# 4  1769965   153802        Drill_Date                          30-Nov-03
# 6  1769966   153802  Drilling_Company  "Layne Drilling Pty. Ltd., Perth"
# 7  1769967   153802          HoleDiam                              135mm
# 8  1769968   153802               PSI                                300
# 9  1769969   153802          Prospect                        Silverstone
#
#   modifieddate modifiedby mrtdetailid
# 0          NaN        NaN      116852
# 1          NaN        NaN      116853
# 2          NaN        NaN      116854
# 3          NaN        NaN      116855
# 4          NaN        NaN      116856
# 6          NaN        NaN      116857
# 7          NaN        NaN      116858
# 8          NaN        NaN      116859
# 9          NaN        NaN      116861

# %% [markdown]
# We can see that for drillhole# 153802: <br>
# RL = Elevation = 359.251 <br>
# MaxDepth = TD =127<br>
#
# Now, let's look at another hole (# 792833):

# %%
collarattr.loc[collarattr['collarid'] == '792942']
# Out:
#           id collarid   attributecolumn                  attributevalue  \
# 141  9597660   792942                RL                         366.147
# 142  9597661   792942         Depth (m)                             160
# 143  9597662   792942       MGA Azimuth                          317.80
# 144  9597663   792942               Dip                          -59.59
# 145  9597664   792942        Drill Type                              RC
# 146  9597665   792942              Grid                  "GDA94, MGA50"
# 147  9597666   792942  Drilling Company  "Strange Drilling, Kalgoorlie"
# 148  9597667   792942    Date Completed                        13/05/06
#
#     modifieddate modifiedby mrtdetailid
# 141          NaN        NaN      511733
# 142          NaN        NaN      511734
# 143          NaN        NaN      511735
# 144          NaN        NaN      511736
# 145          NaN        NaN      511737
# 146          NaN        NaN      511738
# 147          NaN        NaN      511739
# 148          NaN        NaN      511740

# %% [markdown]
# We can observe that this time: <br>
# RL = RL = 366.147 <br>
# MaxDepth = Depth (m) =160<br>
#
# In order to pullout the corresponding RL and MaxDepth values for each drillhole, it was necessary to build a thesaurus.
# Here is a quick look into the <b>RL and MaxDepth thesaurus</b>:

# %%
rl_maxdepth_dic= pd.read_csv(rl_maxdepth_dic_file,encoding = encoding_2, dtype='object')
rl_maxdepth_dic.loc[rl_maxdepth_dic['cet_attributecolumn'] == 'rl']
# Out:
#       attributecolumn cet_attributecolumn
# 111          """RL"""                  rl
# 112  "Nominal\r\nRL "                  rl
# 113         "RLLocal"                  rl
# 114          "RLOrig"                  rl
# 115    "RLSurvMethod"                  rl
# ..                ...                 ...
# 505         SUR DEPTH                  rl
# 506         RL_Method                  rl
# 507     Depth_Start_m                  rl
# 509         ELEVATION                  rl
# 510          Local_RL                  rl
#
# [357 rows x 2 columns]

# %%
rl_maxdepth_dic.loc[rl_maxdepth_dic['cet_attributecolumn'] == 'maxdepth']
# Out:
#          attributecolumn cet_attributecolumn
# 0                     TD            maxdepth
# 1            Total depth            maxdepth
# 2            """DEPTH"""            maxdepth
# 3        """TOT_DEPTH"""            maxdepth
# 4    "Final\r\nDepth(m)"            maxdepth
# ..                   ...                 ...
# 488         Survey Depth            maxdepth
# 489            Sur_Depth            maxdepth
# 490            EOH_depth            maxdepth
# 491      Precollar Depth            maxdepth
# 508               "depth            maxdepth
#
# [154 rows x 2 columns]

# %% [markdown]
# Using the thesaurus and a little bit of code and cleaning up, we can extract the collar information.
#     1. CollarID
#     2. HoleId
#     3. Longitude
#     4. Latitude
#     5. RL
#     6. MaxDepth
#     7. X
#     8. Y

# %%
dh2l.collar_attr_col_dic(rl_maxdepth_dic_file)
dh2l.collar_collarattr_final(collar_file, collarattr_file, rl_maxdepth_dic_file, DB_Collar_Export)
DB_Collar_Export_table=pd.read_csv(DB_Collar_Export,encoding = encoding_2, dtype='object')
DB_Collar_Export_table= DB_Collar_Export_table.loc[:, ~DB_Collar_Export_table.columns.str.contains('^Unnamed')]
print(DB_Collar_Export_table)
# Out:
#     CollarID                    HoleId Longitude  Latitude       RL MaxDepth
# 0    1146526  71288Minjar NorthSSDD006   116.948  -28.8991  356.255    546.4
# 1    1146528  71288Minjar NorthSSDD008   116.947  -28.9021  356.871    405.0
# 2    1146530  71288Minjar NorthSSDD010   116.949  -28.9083  360.214    249.0
# 3    1146531  71288Minjar NorthSSDD011   116.948  -28.9002  357.153    468.0
# 4    1146650  71288Minjar NorthSSDD005   116.948  -28.9002  357.156      150
# ..       ...                       ...       ...       ...      ...      ...
# 127   931215         79530KararaLSC015   117.151  -29.4116  315.535      124
# 128   931216         79530KararaLSC016   117.148   -29.426  361.603      158
# 129   931217         79530KararaLSC017   117.144  -29.4045  323.052      136
# 130   931218         79530KararaLSC018   117.151  -29.4335  365.334      248
# 131   931219         79530KararaLSD006   117.153  -29.4336  368.845    260.7
#
# [132 rows x 6 columns]

# %%
dh2l.plot_collar (DB_Collar_Export, geology)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\plotting.py:471: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "Only specify one of 'column' or 'color'. Using 'color'.", UserWarning

# %% [markdown]
# Let's also calculate for the projected coordinates:

# %%
DB_Collar_Export_table = DB_Collar_Export_table.loc[:, ~DB_Collar_Export_table.columns.str.contains('^Unnamed')]
DB_Collar_Export_table[['X','Y']] = DB_Collar_Export_table.apply(dh2l.convert_coords,axis=1)
DB_Collar_Export_table.to_csv(DB_Collar_Export)
print(DB_Collar_Export_table)
# Out:
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# ...
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\00103098\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#     CollarID                    HoleId Longitude  Latitude       RL MaxDepth  \
# 0    1146526  71288Minjar NorthSSDD006   116.948  -28.8991  356.255    546.4
# 1    1146528  71288Minjar NorthSSDD008   116.947  -28.9021  356.871    405.0
# 2    1146530  71288Minjar NorthSSDD010   116.949  -28.9083  360.214    249.0
# 3    1146531  71288Minjar NorthSSDD011   116.948  -28.9002  357.153    468.0
# 4    1146650  71288Minjar NorthSSDD005   116.948  -28.9002  357.156      150
# ..       ...                       ...       ...       ...      ...      ...
# 127   931215         79530KararaLSC015   117.151  -29.4116  315.535      124
# 128   931216         79530KararaLSC016   117.148   -29.426  361.603      158
# 129   931217         79530KararaLSC017   117.144  -29.4045  323.052      136
# 130   931218         79530KararaLSC018   117.151  -29.4335  365.334      248
# 131   931219         79530KararaLSD006   117.153  -29.4336  368.845    260.7
#
#                  X             Y
# 0    494930.292293  6.803192e+06
# 1    494832.946487  6.802860e+06
# 2    495028.225204  6.802173e+06
# 3    494930.345746  6.803070e+06
# 4    494930.345746  6.803070e+06
# ..             ...           ...
# 127  514648.754909  6.746402e+06
# 128  514355.695351  6.744807e+06
# 129  513970.643608  6.747189e+06
# 130  514645.613436  6.743975e+06
# 131  514839.580770  6.743964e+06
#
# [132 rows x 8 columns]

# %% [markdown]
# ## Exporting Survey Data

# %% [markdown]
#  The same approach is done for survey data. Let's take a look at <b>dhsurvey</b> and <b>dhsurveyattr</b>.

# %%
dhsurvey= pd.read_csv(dhsurvey_file,encoding = encoding_2, dtype='object')
#dhsurvey.head()
dhsurvey.loc[dhsurvey['id'] == '318088']
# Out:
#        id collarid depth units accuracy                 loaddate   loadby  \
# 1  318088   153802   120   NaN      NaN  2011-07-18 09:34:26.913  MIGPSMB
#
#   modifieddate modifiedby mrtfileid  dip azimuth
# 1          NaN        NaN      5256  NaN     NaN

# %%
dhsurveyattr= pd.read_csv(dhsurveyattr_file,encoding = encoding_2, dtype='object')
dhsurveyattr.loc[dhsurveyattr['dhsurveyid'] == '318088']
# Out:
#         id dhsurveyid attributecolumn attributevalue                 loaddate  \
# 5  1855500     318088             Dip            -52  2011-07-18 09:34:26.913
# 6  1855501     318088         Azimuth             90  2011-07-18 09:34:26.913
# 7  1855502     318088         Azimuth             87  2011-07-18 09:34:26.913
# 8  1855503     318088      Instrument        Eastman  2011-07-18 09:34:26.913
# 9  1855504     318088        Prospect    Silverstone  2011-07-18 09:34:26.913
#
#     loadby modifieddate modifiedby mrtdetailid
# 5  MIGPSMB          NaN        NaN      116918
# 6  MIGPSMB          NaN        NaN      116919
# 7  MIGPSMB          NaN        NaN      116920
# 8  MIGPSMB          NaN        NaN      116922
# 9  MIGPSMB          NaN        NaN      116923

# %% [markdown]
# This time we use an <b> Azimuth_Dip Thesaurus </b>.

# %%
survey_dic= pd.read_csv(survey_dic_file,encoding = encoding_2, dtype='object')
survey_dic.loc[survey_dic['new_name'] == 'AZI']
# Out:
#            attr_col new_name
# 0           Aximuth      AZI
# 1                AZ      AZI
# 2          AZ_COMET      AZI
# 3          AZ_Eelya      AZI
# 4        AZ_MGX_LOC      AZI
# 5          AZ_Webbs      AZI
# 6              AZIM      AZI
# 7              Azim      AZI
# 8           AZIMUTH      AZI
# 9           Azimuth      AZI
# 10          azimuth      AZI
# 11       Azimuth(T)      AZI
# 12    Azimuth_Mayan      AZI
# 13     Azimuth_TRUE      AZI
# 14     Azimuth_True      AZI
# 15  GILBEYS AZIMUTH      AZI
# 16      WMC AZIMUTH      AZI
# 17      GILBEYS AZI      AZI
# 18           AZI(T)      AZI

# %%
survey_dic.loc[survey_dic['new_name'] == 'DIP']
# Out:
#         attr_col new_name
# 142          Dip      DIP
# 143          DIP      DIP
# 144          dip      DIP
# 145   Dip (deg.)      DIP
# 146        Dip_2      DIP
# 147          INC      DIP
# 148  Inclination      DIP
# 149   DIP (deg.)      DIP

# %%
dh2l.survey_attr_col_dic(survey_dic_file)
dh2l.survey_final(dhsurvey_file,dhsurveyattr_file, DB_Survey_Export)
dhsurvey= pd.read_csv(DB_Survey_Export,encoding = encoding_2, dtype='object')
dhsurvey= dhsurvey.loc[:, ~dhsurvey.columns.str.contains('^Unnamed')]
print(dhsurvey)
# Out:
#      CollarID  Depth Azimuth    Dip
# 0      153802    0.0    90.0  -50.0
# 1      153802  120.0    90.0  -90.0
# 2      153803    0.0    90.0  -55.0
# 3      153803  130.0    90.0  -90.0
# 4      153804    0.0    90.0  -60.0
# ...       ...    ...     ...    ...
# 1346  1233228  180.0   137.2  -90.0
# 1347  1233228  200.0   137.3  -90.0
# 1348  1233228  220.0   137.4  -90.0
# 1349  1233228  230.0   137.4  -90.0
# 1350  1233229    0.0   135.0  -60.0
#
# [1351 rows x 4 columns]

# %% [markdown]
# Let's also calculate the downhole xyz from the depth, azimuth and dip values using the Minimum Curvature Method. It smooths two straight-line segments of the Balanced Tangential Method by using the Ratio Factor (RF = 2*tan(dl/2)/dl).
#
# <img src='./graphics/Minimum-Curvature-Method.jpg'>
#
# Where:
# MD = Measured Depth between surveys
# I1 = Inclination (angle) of upper survey in degrees
# I2 = Inclination (angle) of lower in degrees
# Az1= Azimuth direction of upper survey
# Az2 = Azimuth direction of lower survey
# RF = Ratio Factor
# ß  = the dog leg angle.
#
# Sources:
# http://www.drillingformulas.com/minimum-curvature-method/ <br>
# https://gis.stackexchange.com/questions/13484/how-to-convert-distance-azimuth-dip-to-xyz <br>
# http://www.cgg.com/data//1/rec_docs/2269_MinimumCurvatureWellPaths.pdf`<br>

# %%
dh2l.convert_survey(DB_Collar_Export,DB_Survey_Export, DB_Survey_Export_Calc)
dhsurvey_calc= pd.read_csv(DB_Survey_Export_Calc,encoding = encoding_2, dtype='object')
dhsurvey_calc.dropna()
dhsurvey_calc= dhsurvey_calc.loc[:, ~dhsurvey_calc.columns.str.contains('^Unnamed')]
print(dhsurvey_calc)
# Out:
#      CollarID       Depth     Azimuth         Dip Index              X  \
# 0      153802    0.000000   90.000000  -50.000000     2  495028.106029
# 1      153802    0.000000   90.000000  -50.000000     2  494917.618977
# 2      153803    0.000000   90.000000  -55.000000     4  495028.106029
# 3      153803    0.000000   90.000000  -55.000000     4  494906.041567
# 4      153804    0.000000   90.000000  -60.000000     6  495028.106029
# ...       ...         ...         ...         ...   ...            ...
# 1345  1233228  140.000000  137.400000  -90.000000  1339  482677.460027
# 1346  1233228  160.000000  137.800000  -90.000000  1339  482663.948285
# 1347  1233228  180.000000  137.200000  -90.000000  1339  482650.372272
# 1348  1233228  200.000000  137.300000  -90.000000  1339  482636.821912
# 1349  1233228  220.000000  137.400000  -90.000000  1339  482630.053152
#
#                    Y           Z
# 0     6802449.793954  359.251000
# 1     6802449.793954  319.037002
# 2     6802449.793954  359.132000
# 3     6802449.793954  320.645223
# 4     6802449.793954  359.122000
# ...              ...         ...
# 1345  6775654.582516  395.372524
# 1346  6775669.327996  395.372524
# 1347  6775684.014444  395.372524
# 1348  6775698.724565  395.372524
# 1349  6775706.085535  395.372524
#
# [1350 rows x 8 columns]

# %% [markdown]
# The survey data export includes the following data:
#     1. CollarID
#     2. Depth
#     3. Azimuth
#     4. Dip
#     5. X
#     6. Y
#     7. Z

# %% [markdown]
# ## Exporting Lithology Data

# %% [markdown]
# Again, we have a pair of tables: <b> dhgeology </b> and <b> dhgeologyattr</b>.

# %%
dhgeology= pd.read_csv(dhgeology_file,encoding = encoding_2, dtype='object')
dhgeology.head()
# Out:
#         id collarid fromdepth todepth units accuracy modifieddate modifiedby  \
# 0  2537823   153803        59      61   NaN      NaN          NaN        NaN
# 1  2537824   153803        61      62   NaN      NaN          NaN        NaN
# 2  2537825   153803        62      69   NaN      NaN          NaN        NaN
# 3  2537826   153803        69      72   NaN      NaN          NaN        NaN
# 4  2537827   153803        72      73   NaN      NaN          NaN        NaN
#
#   mrtfileid
# 0      5255
# 1      5255
# 2      5255
# 3      5255
# 4      5255

# %%
dhgeologyattr= pd.read_csv(dhgeologyattr_file,encoding = encoding_2, dtype='object')
dhgeologyattr.head()
# Out:
#          id dhgeologyid       attributecolumn attributevalue modifieddate  \
# 0  20532422     2537765  Weathering_Intensity             ew          NaN
# 1  20532423     2537765              Regolith             Lf          NaN
# 2  20532424     2537765            Lithology1           Czlu          NaN
# 3  20532425     2537765            Grain_Size            vfg          NaN
# 4  20532426     2537765                Colour           bnrd          NaN
#
#   modifiedby mrtdetailid
# 0        NaN      116894
# 1        NaN      116895
# 2        NaN      116896
# 3        NaN      116898
# 4        NaN      116899

# %%
dh2l.litho_attr_val_dic(dic_attr_val_lithology_file)
dh2l.litho_dico (litho_dic_file)
dh2l.clean_up (cleanup_lithology_file)
dh2l.litho_attr_val_with_fuzzy (CET_Litho)

# %%
dh2l.litho_final (collar_file, dhgeology_file, dhgeologyattr_file, dic_attr_col_lithology_file, CET_Litho, DB_Lithology_Export)

# %% [markdown]
# Exporting lithology is a bit more tricky than collar and survey because what we get are rock codes (i.e., BAS, GRA) that have to be further decoded.
# Let's breakdown the steps done in the export.
#
# <img src='./graphics/lithology_thesauri.png'>
#
# First, the Company_LithoCodes are pulled out the same way we did for Collar and Survey. We use a <b> Litho thesaurus (Thesuarus 1) </b> that lists all the attribute columns that refer to lithology.

# %%
dic_att_col_lithology=pd.read_csv(dic_attr_col_lithology_file,encoding = encoding_2, dtype='object')
print(dic_att_col_lithology)
# Out:
#      attributecolumn
# 0       lithological
# 1       lihological
# 2                LIT
# 3               LITH
# 4               Lith
# 5             Lith_1
# 6             LITH_1
# 7        Lith_1_Code
# 8          Lith_code
# 9          lith_code
# 10         Lith_Code
# 11        lith_code1
# 12        Lith_Code1
# 13    Lith_Qualifier
# 14  Lith_Quallifier1
# 15             Lith1
# 16             LITH1
# 17         Lith1_100
# 18         Lith1_101
# 19         Lith1_Cat
# 20        LITH1_CODE
# 21        lith1_code
# 22        Lith1_code
# 23        Lith1_Code
# 24         Lith1Code
# 25         LITHOLOGY
# 26         lithology
# 27         Lithology
# 28      LITHOLOGY  1
# 29       Lithology 1
# 30       Lithology_1
# 31        LITHOLOGY1
# 32        Lithology1
# 33    Main Geol Unit
# 34    Maj. Lithology
# 35        Major Rock
# 36              RCK1
# 37              rck1
# 38              Rock
# 39              ROCK
# 40            Rock 1
# 41             Rock1
# 42             ROCK1
# 43             rock1
# 44          ROCKCODE
# 45          Rockcode
# 46         RockMajor
# 47         wmc_lith1

# %% [markdown]
# The <b> second thesaurus (from logging protocols) </b> decodes the Company_Litho for the corresponding Company_LithoCode.

# %%
dic_attr_val_lithology=pd.read_csv(dic_attr_val_lithology_file,encoding = encoding_2, dtype='object')
dic_attr_val_lithology.head()
# Out:
#   company_id company_code              comapany_litho
# 0      11410           GR                     Granite
# 1      11410           MG                      Gabbro
# 2      11410           SA    Undifferentiated arenite
# 3      11410           CL                        Clay
# 4      12411           Gr  Granitiod undifferentiated

# %% [markdown]
# Before performing the fuzzywuzzy matching, the Company_Litho text is cleaned to remove extra symbols and descriptions. This <b> cleanup_dictionary </b> includes mineral names, ages and qualifiers (i.e, dominant, abundant, minor).

# %%
cleanup_lithology=pd.read_csv(cleanup_lithology_file,encoding = encoding_2, dtype='object')
print(cleanup_lithology)
# Out:
#           clean
# 0      abundant
# 1    actinolite
# 2    adcumulate
# 3      adjacent
# 4      adularia
# ..          ...
# 577     younger
# 578     zeolite
# 579        zinc
# 580      zircon
# 581     zoisite
#
# [582 rows x 1 columns]

# %% [markdown]
# We use the fuzzywuzzy algorithm to standardize the lithologies. The FuzzyWuzzy matching compares the <b> Company_Litho </b> phrase against a <b> lithology thesaurus </b>. FuzzyWuzzy is a library of Python which is used for string matching. Fuzzy string matching is the process of finding strings that match a given pattern. It uses the Levenshtein Distance to calculate the differences between sequences.

# %% [markdown]
# Let's take a look at the <b> Lithology Thesaurus (Thesaurus 3) </b>. Each row refers to one entry. Each synonym is separated by a space.

# %%
lithology_thesaurus=pd.read_csv(litho_dic_file,encoding = encoding_2, dtype='object')
lithology_thesaurus[lithology_thesaurus['clean'].str.contains('Banded_iron_formation')]
# Out:
#                                                  clean
# 244  Banded_iron_formation iron-formationBIF Banded...

# %% [markdown]
# The processor we used to do the matching is: <b>fuzz.token_set_ratio </b>. It tokenize strings, but split the tokens into groups: intersection and remainder before comparing. It is not as strict as a using an exact processor but stricter than a partial match. Having a comprehensive thesaurus allows us this processor to work effectively. For more information on this: https://www.geeksforgeeks.org/fuzzywuzzy-python-library/
#
# Here's the pseudocode:<br>
# &emsp; scores=process.extract(Cleaned_Company_Litho, Litho_Dico, scorer=fuzz.token_set_ratio)<br>
# &emsp; &emsp; for sc in scores:
# &emsp; &emsp; &emsp; if(sc[score]>bestmatch): #better than previous best match<br>
# &emsp; &emsp; &emsp; &emsp; bestmatch =  sc[score]<br>
# &emsp; &emsp; &emsp; &emsp; bestlitho= Litho_Dico[firstword]<br>
# &emsp; &emsp; &emsp; &emsp; if(sc[litho]==Cleaned_Company_Litho[last]): #bonus for being last word in phrase<br>
# &emsp; &emsp; &emsp; &emsp; bestmatch=bestmatch*1.01<br>
# &emsp; &emsp; &emsp; elif (sc[score]==bestmatch): #equal to previous best match<br>
# &emsp; &emsp; &emsp; &emsp; if(sc[0]==words[last]): #bonus for being last word in phrase<br>
# &emsp; &emsp; &emsp; &emsp; &emsp; bestlitho=Litho_Dico[firstword]<br>
# &emsp; &emsp; &emsp; &emsp; &emsp; bestmatch=bestmatch*1.01<br>
# <br>
#
# The pseudocode shows that we input the <b> cleaned Company_Litho </b> and we parse it through a <b> lithology thesaurus </b>. We take in the score for each iteration and if it is greater than the previous match, it stores the <b> score (bestmatch) </b> and the <b> first lithology (CET_Litho) </b> listed in the corresponding lithology thesaurus entry. A bonus is also added to the score if the cleaned Company_Litho's last word matches the thesaurus.
# <br>
# Furthermore, if the match is less than a threshold we set (in this case, 80). The <b> CET_Litho </b> is classified as "unclassified _rock".

# %% [markdown]
# Let's take a look at the results:

# %%
DB_Lithology_Export_View=pd.read_csv(DB_Lithology_Export,encoding = encoding_2, dtype='object')
print(DB_Lithology_Export_View)
# Out:
#      Company_ID CollarID FromDepth ToDepth Company_LithoCode  \
# 0          3050  1146526        23      31                 X
# 1          3050  1146526        23      31                 X
# 2          3050  1146526        31      32                 X
# 3          3050  1146526        31      32                 X
# 4          3050  1146526        32      38                 X
# ...         ...      ...       ...     ...               ...
# 4344       3050   931220     193.3   212.3               Sbl
# 4345       3050   931220     212.3   213.6               Ssh
# 4346       3050   931220     213.6   214.8               Sbl
# 4347       3050   931220     214.8  217.88                 $
# 4348       3050   931220    217.88   229.4                 $
#
#                Company_Litho          CET_Litho Score Unnamed: 8
# 0     breccia origin unknown  unclassified_rock   101        NaN
# 1               unknown rock               rock   101        NaN
# 2     breccia origin unknown  unclassified_rock   101        NaN
# 3               unknown rock               rock   101        NaN
# 4     breccia origin unknown  unclassified_rock   101        NaN
# ...                      ...                ...   ...        ...
# 4344               limestone          limestone   101        NaN
# 4345                   shale           mudstone   101        NaN
# 4346               limestone          limestone   101        NaN
# 4347      massive sulphides    massive_sulphide    91        NaN
# 4348      massive sulphides    massive_sulphide    91        NaN
#
# [4349 rows x 9 columns]

# %% [markdown]
# ## Upscaling Lithology Data

# %% [markdown]
# In order to link and upscale the drillhole information, a <b> hierarchical thesaurus (Thesaurus 4) </b> was also built. The dictionary involved three levels that would upscale a list of 757 rock names to more general rock groups.

# %%
CET_hierarchy_dico = pd.read_csv(CET_hierarchy_dico_file,encoding = encoding_2)

# %%
dh2l.upscale_litho (DB_Lithology_Export, CET_hierarchy_dico_file, DB_Lithology_Upscaled)
Upscaled_Litho= pd.read_csv(DB_Lithology_Upscaled,encoding = encoding_2)
Upscaled_Litho.head()
# Out:
#    Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 0           0        3050   1146526       23.0     31.0                 X
# 1           1        3050   1146526       31.0     32.0                 X
# 2           2        3050   1146526       32.0     38.0                 X
# 3           3        3050   1146526       38.0     39.0                 X
# 4           4        3050   1146526       39.0     42.0                 X
#
#   Company_Litho CET_Litho  Score Level_3                     Level_2  \
# 0  unknown rock      rock    101    rock  natural_superficial_ground
# 1  unknown rock      rock    101    rock  natural_superficial_ground
# 2  unknown rock      rock    101    rock  natural_superficial_ground
# 3  unknown rock      rock    101    rock  natural_superficial_ground
# 4  unknown rock      rock    101    rock  natural_superficial_ground
#
#      Level_1
# 0  surficial
# 1  surficial
# 2  surficial
# 3  surficial
# 4  surficial

# %%
Upscaled_Litho[Upscaled_Litho['Level_1'] == "igneous"]
# Out:
#       Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 35            35        3050   1146526      352.8    356.1                As
# 36            36        3050   1146530      193.3    197.7                As
# 37            37        3050   1146528       76.0     78.0                Ac
# 38            38        3050   1146528       78.0     80.0                Ac
# 39            39        3050   1146528       80.0     84.0                Ac
# ...          ...         ...       ...        ...      ...               ...
# 3885        3885        3050    931217       29.0     60.0               Fgd
# 3886        3886        3050    931217       60.0     64.0               Fgd
# 3887        3887        3050    931217       65.0     66.0               Fgd
# 3890        3890        3050    548917       94.0    103.0                Mg
# 3891        3891        3050    548917      200.0    204.0                 U
#
#          Company_Litho        CET_Litho  Score          Level_3  \
# 35             syenite          syenite    101          syenite
# 36             syenite          syenite    101          syenite
# 37         carbonatite      carbonatite    101      carbonatite
# 38         carbonatite      carbonatite    101      carbonatite
# 39         carbonatite      carbonatite    101      carbonatite
# ...                ...              ...    ...              ...
# 3885      granodiorite     granodiorite    101     granodiorite
# 3886      granodiorite     granodiorite    101     granodiorite
# 3887      granodiorite     granodiorite    101     granodiorite
# 3890            gabbro           gabbro    101           gabbro
# 3891  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
#
#                                       Level_2  Level_1
# 35    intermediate_coarse-grained crystalline  igneous
# 36    intermediate_coarse-grained crystalline  igneous
# 37                         exotic_crystalline  igneous
# 38                         exotic_crystalline  igneous
# 39                         exotic_crystalline  igneous
# ...                                       ...      ...
# 3885        felsic_coarse-grained crystalline  igneous
# 3886        felsic_coarse-grained crystalline  igneous
# 3887        felsic_coarse-grained crystalline  igneous
# 3890         mafic_coarse-grained crystalline  igneous
# 3891                               ultramafic  igneous
#
# [222 rows x 12 columns]

# %%
Upscaled_Litho[Upscaled_Litho['Level_2'] == "ore"]
# Out:
#       Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 163          163        1621   1233095       0.00    12.00               Sif
# 164          164        1621   1233095      12.00    17.00               Sif
# 165          165        1621   1233095      17.00    29.00               Sif
# 166          166        1621   1233095      29.00    35.00               Sif
# 167          167        1621   1233095      35.00    42.00               Sif
# ...          ...         ...       ...        ...      ...               ...
# 3753        3753        3050    931213     183.00   185.00                 S
# 3754        3754        3050    931213     185.00   186.00                 S
# 3755        3755        3050    931213     186.00   190.00                 S
# 3756        3756        3050    931220     214.80   217.88                 $
# 3757        3757        3050    931220     217.88   229.40                 $
#
#            Company_Litho              CET_Litho  Score                Level_3  \
# 163       iron-formation  banded_iron_formation     90  banded_iron_formation
# 164       iron-formation  banded_iron_formation     90  banded_iron_formation
# 165       iron-formation  banded_iron_formation     90  banded_iron_formation
# 166       iron-formation  banded_iron_formation     90  banded_iron_formation
# 167       iron-formation  banded_iron_formation     90  banded_iron_formation
# ...                  ...                    ...    ...                    ...
# 3753   massive sulphides       massive_sulphide     91       massive_sulphide
# 3754   massive sulphides       massive_sulphide     91       massive_sulphide
# 3755   massive sulphides       massive_sulphide     91       massive_sulphide
# 3756  massive sulphides        massive_sulphide     91       massive_sulphide
# 3757  massive sulphides        massive_sulphide     91       massive_sulphide
#
#      Level_2         Level_1
# 163      ore  mineralisation
# 164      ore  mineralisation
# 165      ore  mineralisation
# 166      ore  mineralisation
# 167      ore  mineralisation
# ...      ...             ...
# 3753     ore  mineralisation
# 3754     ore  mineralisation
# 3755     ore  mineralisation
# 3756     ore  mineralisation
# 3757     ore  mineralisation
#
# [2838 rows x 12 columns]

# %%
Upscaled_Litho[Upscaled_Litho['CET_Litho'] == "granodiorite"]
# Out:
#       Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 3867        3867        3050    548917        0.0     19.0               Fgd
# 3868        3868        3050    548917       19.0     27.0               Fgd
# 3869        3869        3050    548917       27.0     31.0               Fgd
# 3870        3870        3050    548917       31.0     39.0               Fgd
# 3871        3871        3050    548917       39.0     41.0               Fgd
# 3872        3872        3050    548917       41.0     50.0               Fgd
# 3873        3873        3050    548917       54.0     55.0               Fgd
# 3874        3874        3050    548917       55.0     60.0               Fgd
# 3875        3875        3050    548917       65.0     73.0               Fgd
# 3876        3876        3050    548917       73.0     87.0               Fgd
# 3877        3877        3050    548917       93.0     94.0               Fgd
# 3878        3878        3050    548917      103.0    105.0               Fgd
# 3879        3879        3050    548917      105.0    109.0               Fgd
# 3880        3880        3050    931217        1.0      2.0               Fgd
# 3881        3881        3050    931217        2.0      8.0               Fgd
# 3882        3882        3050    931217        8.0     12.0               Fgd
# 3883        3883        3050    931217       12.0     16.0               Fgd
# 3884        3884        3050    931217       16.0     29.0               Fgd
# 3885        3885        3050    931217       29.0     60.0               Fgd
# 3886        3886        3050    931217       60.0     64.0               Fgd
# 3887        3887        3050    931217       65.0     66.0               Fgd
#
#      Company_Litho     CET_Litho  Score       Level_3  \
# 3867  granodiorite  granodiorite    101  granodiorite
# 3868  granodiorite  granodiorite    101  granodiorite
# 3869  granodiorite  granodiorite    101  granodiorite
# 3870  granodiorite  granodiorite    101  granodiorite
# 3871  granodiorite  granodiorite    101  granodiorite
# 3872  granodiorite  granodiorite    101  granodiorite
# 3873  granodiorite  granodiorite    101  granodiorite
# 3874  granodiorite  granodiorite    101  granodiorite
# 3875  granodiorite  granodiorite    101  granodiorite
# 3876  granodiorite  granodiorite    101  granodiorite
# 3877  granodiorite  granodiorite    101  granodiorite
# 3878  granodiorite  granodiorite    101  granodiorite
# 3879  granodiorite  granodiorite    101  granodiorite
# 3880  granodiorite  granodiorite    101  granodiorite
# 3881  granodiorite  granodiorite    101  granodiorite
# 3882  granodiorite  granodiorite    101  granodiorite
# 3883  granodiorite  granodiorite    101  granodiorite
# 3884  granodiorite  granodiorite    101  granodiorite
# 3885  granodiorite  granodiorite    101  granodiorite
# 3886  granodiorite  granodiorite    101  granodiorite
# 3887  granodiorite  granodiorite    101  granodiorite
#
#                                 Level_2  Level_1
# 3867  felsic_coarse-grained crystalline  igneous
# 3868  felsic_coarse-grained crystalline  igneous
# 3869  felsic_coarse-grained crystalline  igneous
# 3870  felsic_coarse-grained crystalline  igneous
# 3871  felsic_coarse-grained crystalline  igneous
# 3872  felsic_coarse-grained crystalline  igneous
# 3873  felsic_coarse-grained crystalline  igneous
# 3874  felsic_coarse-grained crystalline  igneous
# 3875  felsic_coarse-grained crystalline  igneous
# 3876  felsic_coarse-grained crystalline  igneous
# 3877  felsic_coarse-grained crystalline  igneous
# 3878  felsic_coarse-grained crystalline  igneous
# 3879  felsic_coarse-grained crystalline  igneous
# 3880  felsic_coarse-grained crystalline  igneous
# 3881  felsic_coarse-grained crystalline  igneous
# 3882  felsic_coarse-grained crystalline  igneous
# 3883  felsic_coarse-grained crystalline  igneous
# 3884  felsic_coarse-grained crystalline  igneous
# 3885  felsic_coarse-grained crystalline  igneous
# 3886  felsic_coarse-grained crystalline  igneous
# 3887  felsic_coarse-grained crystalline  igneous

# %% [markdown]
# Let's also calculate for the X,Y,Z coordinates for FromDepth, ToDepth and its midpoint.

# %%
dh2l.convert_lithology(DB_Collar_Export, DB_Survey_Export, DB_Lithology_Upscaled, DB_Lithology_Export_Calc)
DB_Lithology_Export_Calculated=pd.read_csv(DB_Lithology_Export_Calc)
print(DB_Lithology_Export_Calculated)
# Out:
#       Unnamed: 0  Company_ID   CollarID  FromDepth  ToDepth Company_LithoCode  \
# 0             36        3050   548917.0       0.00    19.00               Fgd
# 1             37        3050   548917.0      19.00    27.00               Fgd
# 2             38        3050   548917.0      27.00    31.00               Fgd
# 3             39        3050   548917.0      31.00    39.00               Fgd
# 4             40        3050   548917.0      39.00    41.00               Fgd
# ...          ...         ...        ...        ...      ...               ...
# 3229        3333        1621  1233228.0     190.50   193.20               Ssh
# 3230        3334        1621  1233228.0     193.20   229.44               Sif
# 3231        3335        1621  1233228.0     229.44   231.13               Sif
# 3232        3336        1621  1233228.0     231.13   233.25               Ssh
# 3233        3337        1621  1233228.0     233.25   245.00               Ssh
#
#        Company_Litho              CET_Litho  Score                Level_3  \
# 0       granodiorite           granodiorite    101           granodiorite
# 1       granodiorite           granodiorite    101           granodiorite
# 2       granodiorite           granodiorite    101           granodiorite
# 3       granodiorite           granodiorite    101           granodiorite
# 4       granodiorite           granodiorite    101           granodiorite
# ...              ...                    ...    ...                    ...
# 3229           shale               mudstone    101               mudstone
# 3230  iron-formation  banded_iron_formation     90  banded_iron_formation
# 3231  iron-formation  banded_iron_formation     90  banded_iron_formation
# 3232           shale               mudstone    101               mudstone
# 3233           shale               mudstone    101               mudstone
#
#       ...            xbt           ybt         zbt            xmt  \
# 0     ...  514164.694405  6.747200e+06  331.316000  514168.725634
# 1     ...  514170.979020  6.747200e+06  313.520157  514171.204428
# 2     ...  514171.204428  6.747200e+06  305.528639  514171.204428
# 3     ...  514171.204428  6.747200e+06  301.528639  514171.204428
# 4     ...  514171.204428  6.747200e+06  293.528639  514171.204428
# ...   ...            ...           ...         ...            ...
# 3229  ...  482789.720025  6.775532e+06  212.354825  482789.720025
# 3230  ...  482789.720025  6.775532e+06  209.654825  482789.720025
# 3231  ...  482789.720025  6.775532e+06  173.414825  482789.720025
# 3232  ...  482789.720025  6.775532e+06  171.724825  482789.720025
# 3233  ...  482789.720025  6.775532e+06  169.604825  482789.720025
#
#                ymt         zmt            xet           yet         zet  \
# 0     6.747200e+06  322.722624  514170.979020  6.747200e+06  313.520157
# 1     6.747200e+06  309.528639  514171.204428  6.747200e+06  305.528639
# 2     6.747200e+06  303.528639  514171.204428  6.747200e+06  301.528639
# 3     6.747200e+06  297.528639  514171.204428  6.747200e+06  293.528639
# 4     6.747200e+06  292.528639  514171.204428  6.747200e+06  291.528639
# ...            ...         ...            ...           ...         ...
# 3229  6.775532e+06  211.004825  482789.720025  6.775532e+06  209.654825
# 3230  6.775532e+06  191.534825  482789.720025  6.775532e+06  173.414825
# 3231  6.775532e+06  172.569825  482789.720025  6.775532e+06  171.724825
# 3232  6.775532e+06  170.664825  482789.720025  6.775532e+06  169.604825
# 3233  6.775532e+06  163.729825  482789.720025  6.775532e+06  157.854825
#
#       Unnamed: 20
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 3229          NaN
# 3230          NaN
# 3231          NaN
# 3232          NaN
# 3233          NaN
#
# [3234 rows x 22 columns]

# %% [markdown]
# ## Export to VTK

# %%
dh2l.intervals2vtk(DB_Lithology_Export_Calc, DB_Lithology_Export_VTK)

# %% [markdown]
# <img src='./graphics/vtk.png'>

# %% [markdown]
# Open Paraview to view the VTK files and have some fun!<br>
# The VTK file output is at \dh2loop\data\export\DB_Lithology_Export.vtp

# %%
#import pyvista
#import pandas as pd
#import numpy as np
#from PVGeo.filters import PointsToTube

#table= pd.read_csv('../data/export/DB_Lithology_Export_Calc.csv',encoding = "ISO-8859-1", dtype='object')
#xb = table['xmt'].values.astype(float)
#yb = table['ymt'].values.astype(float)
#zb = table['zmt'].values.astype(float)

#points = pyvista.PolyData(np.c_[xb,yb,zb])
#points.plot(point_size=10)
#tube = PointsToTube(nearestNbr=True).apply(points)
#tube.plot(color=True)
