# %% [markdown]
# ## Exporting and Text Parsing of Drillhole Data
# This notebook reads in from an export of the PostGIS/PostgreSQL WAMEX (Western Australian Mineral) database. A local subset copy instead of directly connecting to the database is used in this workshop. WAMEX contains mineral exploration reports and data that have lapsed the period of confidentiality. Online access is free of charge at:
# https://www.dmp.wa.gov.au/Geological-Survey/Mineral-exploration-Reports-1401.aspx
#
# From this database export, we pullout the following information: <br>
# 1 ) Collar (CollarID, Longitude, Latitude, RL, MaxDepth) <br>
# 2 ) Survey (CollarID, Depth, Azimuth, Dip) <br>
# 3 ) Lithology (CollarID, From_Depth, To_Depth, Company_LithoCode) <br>
#
# The Survey table is further processed to calculate downhole X,Y,Z using minimum curvature.
# The Lithology table is further processed to decode the Company LithoCodes into their respective lithologies. These lithologies are then standardized across different drilling campaigns and upscaled to be classified into broader rock types.

# %% [markdown]
# ## WAMEX Database
# Let's take a look at what the database information looks like and how these tables are related:
# <a href="./graphics/gswadh_schema.pdf">gswadh_schema.pdf</a>
# <img src='./graphics/gswadh_schema.bmp'>
# <br>
# Today, we will focus on tables necessary for collar, survey and lithology files.
# <img src='./graphics/postgres-database.png'>

# %%
import pandas as pd
from dh2loop import dh2l

# %%
# %run -i "dh2l_config.py"
# Out:
# Default parameters loaded from dh2l_config.py:
# #Database Files
# data_path='../data/'
# wamex_path='../data/wamex/'
# collar_file=wamex_path+'collar.csv'
# collarattr_file=wamex_path+'collarattr.csv'
# dhsurvey_file=wamex_path+'dhsurvey.csv'
# dhsurveyattr_file=wamex_path+'dhsurveyattr.csv'
# dhgeology_file=wamex_path+'dhgeology.csv'
# dhgeologyattr_file=wamex_path+'dhgeologyattr.csv'
#
# #Thesauri
# rl_maxdepth_dic_file= wamex_path+'rl_maxdepth_dic.csv'
# survey_dic_file=wamex_path+'survey_dic.csv'
# dic_attr_col_lithology_file=wamex_path+'dic_att_col_lithology.csv'
# dic_attr_val_lithology_file=wamex_path+'dic_attr_val_lithology_filter.csv'
# cleanup_lithology_file=wamex_path+'cleanup_lithology.csv'
# litho_dic_file=wamex_path+'litho_dic_1.csv'
# CET_hierarchy_dico_file=wamex_path+'hierarchy_dico.csv'
#
# #ExportFiles
# export_path='../data/export/'
# DB_Collar_Export=export_path+'DB_Collar_Export.csv'
# DB_Survey_Export=export_path+'DB_Survey_Export.csv'
# DB_Survey_Export_Calc=export_path+'DB_Survey_Export_Calc.csv'
# CET_Litho=export_path+'CET_Litho.csv'
# DB_Lithology_Export=export_path+'DB_Lithology_Export.csv'
# DB_Lithology_Export_Backup=export_path+'DB_Lithology_Export_Backup.csv'
# DB_Lithology_Upscaled=export_path+'DB_Lithology_Upscaled.csv'
# DB_Lithology_Export_Calc=export_path+'DB_Lithology_Export_Calc.csv'
# DB_Lithology_Export_VTK=export_path+'DB_Lithology_Export.vtp'
#
#
# #Shapefiles
# shapefile_path='../data/shapefile/'
# geology=shapefile_path+'500K_interpgeol16_yalgoo_singleton.shp'
#
# #Projections
# src_crs = {'init': 'EPSG:4326'}  # coordinate reference system for imported dtms (geodetic lat/long WGS84)
# dst_crs = {'init': 'EPSG:28350'} # coordinate system for data
#
# print('Default parameters loaded from dh2l_config.py:')
# with open('../notebooks/dh2l_config.py', 'r') as myfile:
#   data = myfile.read()
#   print(data)
#   myfile.close()
# print('\nModify these parameters in the cell below')
#
# Modify these parameters in the cell below

# %% [markdown]
# ## Exporting Collar Data
#
# Let's take a look at <b>collar</b> and <b>collarattr</b> table:

# %%
collar= pd.read_csv(collar_file,encoding = "ISO-8859-1", dtype='object')
collar.head()
# Out:
#        id                    holeid anumber companyholeid       dataset  \
# 0  153802  69189Minjar NorthSSRC007   69189       SSRC007  Minjar North
# 1  153803  69189Minjar NorthSSRC008   69189       SSRC008  Minjar North
# 2  153804  69189Minjar NorthSSRC009   69189       SSRC009  Minjar North
# 3  153813  69189Minjar NorthSSRC019   69189       SSRC019  Minjar North
# 4  153816  69189Minjar NorthSSRC022   69189       SSRC022  Minjar North
#
#   companyid longitude  latitude istransformed modifieddate modifiedby  \
# 0      3049   116.949  -28.9058          True          NaN        NaN
# 1      3049   116.949  -28.9058          True          NaN        NaN
# 2      3049   116.949  -28.9058          True          NaN        NaN
# 3      3049   116.949  -28.9065          True          NaN        NaN
# 4      3049   116.949  -28.9068          True          NaN        NaN
#
#   mrtfileid holetype maxdepth  \
# 0      5252       RC      127
# 1      5252       RC      130
# 2      5252       RC      120
# 3      5252       RC      174
# 4      5252       RC      146
#
#                                                 geom
# 0  0101000020E610000000000000C33C5D4000000000E0E7...
# 1  0101000020E6100000000000C0C23C5D4000000020E0E7...
# 2  0101000020E610000000000000C23C5D4000000040E0E7...
# 3  0101000020E610000000000040C03C5D40000000E00FE8...
# 4  0101000020E610000000000080C23C5D400000004027E8...

# %%
collarattr= pd.read_csv(collarattr_file,encoding = "ISO-8859-1", dtype='object')
collarattr.loc[collarattr['collarid'] == '153802']
# Out:
#         id collarid   attributecolumn                     attributevalue  \
# 0  1769961   153802         Elevation                            359.251
# 1  1769962   153802                TD                                127
# 2  1769963   153802     Drilling_code                                 RC
# 3  1769964   153802          Tenement                            M59/421
# 4  1769965   153802        Drill_Date                          30-Nov-03
# 6  1769966   153802  Drilling_Company  "Layne Drilling Pty. Ltd., Perth"
# 7  1769967   153802          HoleDiam                              135mm
# 8  1769968   153802               PSI                                300
# 9  1769969   153802          Prospect                        Silverstone
#
#   modifieddate modifiedby mrtdetailid
# 0          NaN        NaN      116852
# 1          NaN        NaN      116853
# 2          NaN        NaN      116854
# 3          NaN        NaN      116855
# 4          NaN        NaN      116856
# 6          NaN        NaN      116857
# 7          NaN        NaN      116858
# 8          NaN        NaN      116859
# 9          NaN        NaN      116861

# %% [markdown]
# We can see that for drillhole# 153802: <br>
# RL = Elevation = 359.251 <br>
# MaxDepth = TD =127<br>
#
# Now, let's look at another hole (# 792833):

# %%
collarattr.loc[collarattr['collarid'] == '792942']
# Out:
#           id collarid   attributecolumn                  attributevalue  \
# 141  9597660   792942                RL                         366.147
# 142  9597661   792942         Depth (m)                             160
# 143  9597662   792942       MGA Azimuth                          317.80
# 144  9597663   792942               Dip                          -59.59
# 145  9597664   792942        Drill Type                              RC
# 146  9597665   792942              Grid                  "GDA94, MGA50"
# 147  9597666   792942  Drilling Company  "Strange Drilling, Kalgoorlie"
# 148  9597667   792942    Date Completed                        13/05/06
#
#     modifieddate modifiedby mrtdetailid
# 141          NaN        NaN      511733
# 142          NaN        NaN      511734
# 143          NaN        NaN      511735
# 144          NaN        NaN      511736
# 145          NaN        NaN      511737
# 146          NaN        NaN      511738
# 147          NaN        NaN      511739
# 148          NaN        NaN      511740

# %% [markdown]
# We can observe that this time: <br>
# RL = RL = 366.147 <br>
# MaxDepth = Depth (m) =160<br>
#
# In order to pullout the corresponding RL and MaxDepth values for each drillhole, it was necessary to build a thesaurus.
# Here is a quick look into the <b>RL and MaxDepth thesaurus</b>:

# %%
rl_maxdepth_dic= pd.read_csv(rl_maxdepth_dic_file,encoding = "ISO-8859-1", dtype='object')
rl_maxdepth_dic.loc[rl_maxdepth_dic['cet_attributecolumn'] == 'rl']
# Out:
#       attributecolumn cet_attributecolumn
# 111          """RL"""                  rl
# 112  "Nominal\r\nRL "                  rl
# 113         "RLLocal"                  rl
# 114          "RLOrig"                  rl
# 115    "RLSurvMethod"                  rl
# 116             325RL                  rl
# 117            ACC_RL                  rl
# 118            ADJ_RL                  rl
# 119       Adjusted_RL                  rl
# 120          AGD84_RL                  rl
# 121           AGD84RL                  rl
# 122       AGD84Z51_RL                  rl
# 123            AHD RL                  rl
# 124            AHD_RL                  rl
# 125       AHD_RL    N                  rl
# 126            AHDmRL                  rl
# 127             AHDRL                  rl
# 128              AHrl                  rl
# 129           amg  rl                  rl
# 130           AMG _RL                  rl
# 131            AMG RL                  rl
# 132         AMG_84_RL                  rl
# 133           AMG_mRL                  rl
# 134            amg_rl                  rl
# 135       amg_rl    N                  rl
# 136       AMG_RL_Mine                  rl
# 137          AMG66_RL                  rl
# 138          AMG84_RL                  rl
# 139             AmgRl                  rl
# 140         Approx RL                  rl
# ..                ...                 ...
# 438          ZMINE_RL                  rl
# 439               zRL                  rl
# 446           Plot_RL                  rl
# 447               R.L                  rl
# 449          AMG48_RL                  rl
# 450      Precollar_RL                  rl
# 460       RL_REGIONAL                  rl
# 461          LOCAL_RL                  rl
# 463              Elev                  rl
# 465            REF_RL                  rl
# 466               ELV                  rl
# 484       Start_depth                  rl
# 492            AMG_RL                  rl
# 493                rl                  rl
# 494              R.L.                  rl
# 495            REG_RL                  rl
# 496            Nat_RL                  rl
# 497          LOCAL_RL                  rl
# 498          RL_LOCAL                  rl
# 499       RL_REGIONAL                  rl
# 500        PROJECT_RL                  rl
# 501          elvation                  rl
# 502         elevation                  rl
# 503       RL(assumed)                  rl
# 504         RL_SURVEY                  rl
# 505         SUR DEPTH                  rl
# 506         RL_Method                  rl
# 507     Depth_Start_m                  rl
# 509         ELEVATION                  rl
# 510          Local_RL                  rl
#
# [357 rows x 2 columns]

# %%
rl_maxdepth_dic.loc[rl_maxdepth_dic['cet_attributecolumn'] == 'maxdepth']
# Out:
#             attributecolumn cet_attributecolumn
# 0                        TD            maxdepth
# 1               Total depth            maxdepth
# 2               """DEPTH"""            maxdepth
# 3           """TOT_DEPTH"""            maxdepth
# 4       "Final\r\nDepth(m)"            maxdepth
# 5           "Hole\r\nDepth"            maxdepth
# 6    "Max Depth\r\n metres"            maxdepth
# 7           "Max Depth\r\n"            maxdepth
# 8                  AC Depth            maxdepth
# 9              Actual Depth            maxdepth
# 10              Auger_DEPTH            maxdepth
# 11          BHID1 Max_Depth            maxdepth
# 12               core_depth            maxdepth
# 13              DD Depth HQ            maxdepth
# 14              DD Depth NQ            maxdepth
# 15                 DD_Depth            maxdepth
# 16                  DDDepth            maxdepth
# 17                DDH_Depth            maxdepth
# 18                    Depth            maxdepth
# 19        DEPTH     N  7  2            maxdepth
# 20                DEPTH   7            maxdepth
# 21                Depth   m            maxdepth
# 22               DEPTH  (m)            maxdepth
# 23              Depth (EOH)            maxdepth
# 24                DEPTH (M)            maxdepth
# 25           Depth (metres)            maxdepth
# 26               DEPTH _(m)            maxdepth
# 27                Depth _RC            maxdepth
# 28               Depth Diam            maxdepth
# 29            Depth Drilled            maxdepth
# ..                      ...                 ...
# 457              Hole_depth            maxdepth
# 458                Maxdepth            maxdepth
# 459                  Tdepth            maxdepth
# 462                  TDEPTH            maxdepth
# 464                Maxdepth            maxdepth
# 467        Depth pre_collar            maxdepth
# 468                 T_depth            maxdepth
# 469                  "Depth            maxdepth
# 470             toatl_depth            maxdepth
# 471                 DEPTH M            maxdepth
# 472         PreCollar_Depth            maxdepth
# 473              Hole_depth            maxdepth
# 474               MAX_DEPTH            maxdepth
# 475             total_depth            maxdepth
# 476             TOTAL DEPTH            maxdepth
# 477                Maxdepth            maxdepth
# 478             TOTAL DEPTH            maxdepth
# 479              Final_dpth            maxdepth
# 480                 T_depth            maxdepth
# 481                 t_depth            maxdepth
# 482               End_depth            maxdepth
# 483               EOH_DEPTH            maxdepth
# 485               EOH DEPTH            maxdepth
# 486            SURVEY DEPTH            maxdepth
# 487            SURVEY_DEPTH            maxdepth
# 488            Survey Depth            maxdepth
# 489               Sur_Depth            maxdepth
# 490               EOH_depth            maxdepth
# 491         Precollar Depth            maxdepth
# 508                  "depth            maxdepth
#
# [154 rows x 2 columns]

# %% [markdown]
# Using the thesaurus and a little bit of code and cleaning up, we can extract the collar information.
#     1. CollarID
#     2. HoleId
#     3. Longitude
#     4. Latitude
#     5. RL
#     6. MaxDepth
#     7. X
#     8. Y

# %%
dh2l.collar_attr_col_dic(rl_maxdepth_dic_file)
dh2l.collar_collarattr_final(collar_file, collarattr_file, rl_maxdepth_dic_file, DB_Collar_Export)
DB_Collar_Export_table=pd.read_csv(DB_Collar_Export,encoding = "ISO-8859-1", dtype='object')
DB_Collar_Export_table= DB_Collar_Export_table.loc[:, ~DB_Collar_Export_table.columns.str.contains('^Unnamed')]
print(DB_Collar_Export_table)
# Out:
#     CollarID                     HoleId Longitude  Latitude       RL MaxDepth
# 0    1146528   71288Minjar NorthSSDD008   116.947  -28.9021  356.255    546.4
# 1    1146530   71288Minjar NorthSSDD010   116.949  -28.9083  356.871    405.0
# 2    1146531   71288Minjar NorthSSDD011   116.948  -28.9002  360.214    249.0
# 119   872817             63990MNJSWD311   116.918  -29.1486     1000      111
# 120   872818             63990MNJSWD312   116.908   -29.144     1000      119
# 121   872842             63990MNJSWD361   116.915  -29.1612     1000      119
# 122   872843             63990MNJSWD362   116.914  -29.1612     1000      104
# 123   931212          79530KararaLSC010   117.148  -29.4188     1000      101
# 124   931213          79530KararaLSC011    117.15  -29.4188  340.915      234
# 125   931214          79530KararaLSC014   117.144  -29.4116  339.331      206
# 126   931215          79530KararaLSC015   117.151  -29.4116   331.21      228
# 127   931216          79530KararaLSC016   117.148   -29.426  315.535      124
# 128   931217          79530KararaLSC017   117.144  -29.4045  361.603      158
# 129   931218          79530KararaLSC018   117.151  -29.4335  323.052      136
# 130   931219          79530KararaLSD006   117.153  -29.4336  365.334      248
# 131   931220          79530KararaLSD007   117.151  -29.4405  368.845    260.7
#
# [132 rows x 6 columns]

# %%
dh2l.plot_collar (DB_Collar_Export, geology)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\plotting.py:404: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)

# %% [markdown]
# Let's also calculate for the projected coordinates:

# %%
DB_Collar_Export_table = DB_Collar_Export_table.loc[:, ~DB_Collar_Export_table.columns.str.contains('^Unnamed')]
DB_Collar_Export_table[['X','Y']] = DB_Collar_Export_table.apply(dh2l.convert_coords,axis=1)
DB_Collar_Export_table.to_csv(DB_Collar_Export)
print(DB_Collar_Export_table)
# Out:
#     CollarID                     HoleId Longitude  Latitude       RL MaxDepth  \
# 0    1146528   71288Minjar NorthSSDD008   116.947  -28.9021  356.255    546.4
# 1    1146530   71288Minjar NorthSSDD010   116.949  -28.9083  356.871    405.0
# 2    1146531   71288Minjar NorthSSDD011   116.948  -28.9002  360.214    249.0
# 3    1146650   71288Minjar NorthSSDD005   116.948  -28.9002  357.153    468.0
# 4    1233095         82655KararaBHN1001   116.818  -29.1504  357.156      150
# 5    1233096         82655KararaBHN1002   116.818   -29.151  383.557      108
# 6    1233098         82655KararaKAR1001   116.775  -29.1886  382.505      108
# 7    1233099         82655KararaKAR1002   116.775  -29.1885  414.225    713.4
# 8    1233100         82655KararaKAR1003   116.774  -29.1913  414.093    620.2
# 9    1233101         82655KararaKAR1004   116.775  -29.1913  439.337      200
# 10   1233102         82655KararaKAR1005   116.776  -29.1913  439.583      186
# 11   1233103         82655KararaKAR1006   116.776  -29.1801  420.274      150
# 12   1233104         82655KararaKAR1007   116.777  -29.1788  427.641      250
# 13   1233105         82655KararaKAR1008   116.777  -29.1781  413.069      250
# 14   1233106         82655KararaKAR1009   116.778  -29.1772  417.671      236
# 15   1233107         82655KararaKAR1010    116.78  -29.1763  411.446      162
# 16   1233108         82655KararaKAR1011   116.785  -29.1731  411.607      240
# 17   1233109          82655KararaMKC309   116.822  -29.1489  377.475      150
# 18   1233110          82655KararaMKC430   116.823  -29.1473  408.771      180
# 19   1233113          82655KararaMKC433   116.819  -29.1515  378.195      150
# 20   1233114          82655KararaMKC434    116.82  -29.1502  377.159      221
# 21   1233115          82655KararaMKC435    116.82  -29.1502  398.064      197
# 22   1233116          82655KararaMKC436   116.818  -29.1517  397.877      162
# 15   478608.448865  6.772462e+06
# 16   479093.973159  6.772817e+06
# 17   482687.702481  6.775504e+06
# 18   482784.696009  6.775682e+06
# 19   482396.364944  6.775216e+06
# 20   482493.402352  6.775360e+06
# 21   482493.402352  6.775360e+06
# 22   482299.141406  6.775193e+06
# 23   482784.762691  6.775637e+06
# 24   482396.467242  6.775149e+06
# 25   482590.459075  6.775493e+06
# 26   482493.300625  6.775426e+06
# 27   482493.317580  6.775415e+06
# 28   482493.334534  6.775404e+06
# 29   482687.685715  6.775515e+06
# ..             ...           ...
# 102  493855.141915  6.808299e+06
# 103  493855.235974  6.808122e+06
# 104  479288.247532  6.772928e+06
# 105  479288.307763  6.772895e+06
# 106  479384.606872  6.773416e+06
# 107  478416.219365  6.771276e+06
# 108  478513.673108  6.771154e+06
# 109  478513.610585  6.771187e+06
# 110  478414.628502  6.772118e+06
# 111  478512.026848  6.772029e+06
# 112  496693.793636  6.773323e+06
# 113  497569.251093  6.771983e+06
# 114  497763.689327  6.772094e+06
# 115  492606.956697  6.777498e+06
# 116  491925.330790  6.778473e+06
# 117  492121.616942  6.775980e+06
# 118  492024.322029  6.776024e+06
# 119  492024.654110  6.775548e+06
# 120  491051.651963  6.776057e+06
# 121  491733.881993  6.774152e+06
# 122  491636.633508  6.774152e+06
# 123  514356.707640  6.745604e+06
# 124  514550.717432  6.745604e+06
# 125  513969.672792  6.746403e+06
# 126  514648.754909  6.746402e+06
# 127  514355.695351  6.744807e+06
# 128  513970.643608  6.747189e+06
# 129  514645.613436  6.743975e+06
# 130  514839.580770  6.743964e+06
# 131  514644.608861  6.743200e+06
#
# [132 rows x 8 columns]

# %% [markdown]
# ## Exporting Survey Data

# %% [markdown]
#  The same approach is done for survey data. Let's take a look at <b>dhsurvey</b> and <b>dhsurveyattr</b>.

# %%
dhsurvey= pd.read_csv(dhsurvey_file,encoding = "ISO-8859-1", dtype='object')
#dhsurvey.head()
dhsurvey.loc[dhsurvey['id'] == '318088']
# Out:
#        id collarid depth units accuracy                 loaddate   loadby  \
# 1  318088   153802   120   NaN      NaN  2011-07-18 09:34:26.913  MIGPSMB
#
#   modifieddate modifiedby mrtfileid  dip azimuth
# 1          NaN        NaN      5256  NaN     NaN

# %%
dhsurveyattr= pd.read_csv(dhsurveyattr_file,encoding = "ISO-8859-1", dtype='object')
dhsurveyattr.loc[dhsurveyattr['dhsurveyid'] == '318088']
# Out:
#         id dhsurveyid attributecolumn attributevalue                 loaddate  \
# 5  1855500     318088             Dip            -52  2011-07-18 09:34:26.913
# 6  1855501     318088         Azimuth             90  2011-07-18 09:34:26.913
# 7  1855502     318088         Azimuth             87  2011-07-18 09:34:26.913
# 8  1855503     318088      Instrument        Eastman  2011-07-18 09:34:26.913
# 9  1855504     318088        Prospect    Silverstone  2011-07-18 09:34:26.913
#
#     loadby modifieddate modifiedby mrtdetailid
# 5  MIGPSMB          NaN        NaN      116918
# 6  MIGPSMB          NaN        NaN      116919
# 7  MIGPSMB          NaN        NaN      116920
# 8  MIGPSMB          NaN        NaN      116922
# 9  MIGPSMB          NaN        NaN      116923

# %% [markdown]
# This time we use an <b> Azimuth_Dip Thesaurus </b>.

# %%
survey_dic= pd.read_csv(survey_dic_file,encoding = "ISO-8859-1", dtype='object')
survey_dic.loc[survey_dic['new_name'] == 'AZI']
# Out:
#            attr_col new_name
# 0           Aximuth      AZI
# 1                AZ      AZI
# 2          AZ_COMET      AZI
# 3          AZ_Eelya      AZI
# 4        AZ_MGX_LOC      AZI
# 5          AZ_Webbs      AZI
# 6              AZIM      AZI
# 7              Azim      AZI
# 8           AZIMUTH      AZI
# 9           Azimuth      AZI
# 10          azimuth      AZI
# 11       Azimuth(T)      AZI
# 12    Azimuth_Mayan      AZI
# 13     Azimuth_TRUE      AZI
# 14     Azimuth_True      AZI
# 15  GILBEYS AZIMUTH      AZI
# 16      WMC AZIMUTH      AZI
# 17      GILBEYS AZI      AZI
# 18           AZI(T)      AZI

# %%
survey_dic.loc[survey_dic['new_name'] == 'DIP']
# Out:
#         attr_col new_name
# 142          Dip      DIP
# 143          DIP      DIP
# 144          dip      DIP
# 145   Dip (deg.)      DIP
# 146        Dip_2      DIP
# 147          INC      DIP
# 148  Inclination      DIP
# 149   DIP (deg.)      DIP

# %%
dh2l.survey_attr_col_dic(survey_dic_file)
dh2l.survey_final(dhsurvey_file,dhsurveyattr_file, DB_Survey_Export)
dhsurvey= pd.read_csv(DB_Survey_Export,encoding = "ISO-8859-1", dtype='object')
dhsurvey= dhsurvey.loc[:, ~dhsurvey.columns.str.contains('^Unnamed')]
print(dhsurvey)
# Out:
#      CollarID  Depth Azimuth     Dip
# 0      153802    0.0    90.0   -50.0
# 1      153802  120.0    90.0   -90.0
# 2      153803    0.0    90.0   -55.0
# 3      153803  130.0    90.0   -90.0
# 4      153804    0.0    90.0   -60.0
# 5      153804   60.0    90.0   -90.0
# 6      153804  120.0    90.0   -90.0
# 7      153813    0.0    90.0   -60.0
# 8      153813   50.0    90.0   -90.0
# 9      153813  100.0    90.0   -90.0
# 10     153813  174.0    90.0   -90.0
# 11     153816    0.0    90.0   -60.0
# 12     153816   50.0    90.0   -90.0
# 13     153816  100.0    90.0   -90.0
# 14     153816  146.0    90.0   -90.0
# 15     153834    0.0    90.0   -60.0
# 16     153834   54.0    90.0   -90.0
# 17     153834  102.0    90.0   -90.0
# 18     153834  138.0    90.0   -90.0
# 19     153835    0.0    90.0   -60.0
# 20     153835   50.0    90.0   -90.0
# 21     153835  100.0    90.0   -90.0
# 22     153835  150.0    90.0   -90.0
# 23     548917    0.0    89.6  -60.79
# 24     548917   20.0    90.4   -90.0
# 25     548917   40.0    93.1   -90.0
# 26     548917   60.0    95.0   -90.0
# 27     548917   80.0    96.1   -90.0
# 28     548917  100.0    96.7   -90.0
# 29     548917  120.0    96.5   -90.0
# ...       ...    ...     ...     ...
# 1321  1233226  280.0   129.7   -90.0
# 1322  1233226  300.0   129.5   -90.0
# 1323  1233227    0.0   135.4  -58.24
# 1324  1233227   20.0   136.6   -90.0
# 1325  1233227   40.0   138.0   -90.0
# 1326  1233227   60.0   139.7   -90.0
# 1327  1233227   80.0   143.6   -90.0
# 1328  1233227  100.0   147.4   -90.0
# 1329  1233227  120.0   146.7   -90.0
# 1330  1233227  140.0   146.2   -90.0
# 1331  1233227  160.0   146.1   -90.0
# 1332  1233227  180.0   146.8   -90.0
# 1333  1233227  200.0   145.4   -90.0
# 1334  1233227  220.0   145.4   -90.0
# 1335  1233227  240.0   145.4   -90.0
# 1336  1233227  250.0   145.0   -90.0
# 1337  1233228    0.0   137.8  -55.47
# 1338  1233228   20.0   137.1   -90.0
# 1339  1233228   40.0   137.4   -90.0
# 1340  1233228   60.0   137.5   -90.0
# 1341  1233228   80.0   137.4   -90.0
# 1342  1233228  100.0   137.4   -90.0
# 1343  1233228  120.0   137.4   -90.0
# 1344  1233228  140.0   137.4   -90.0
# 1345  1233228  160.0   137.8   -90.0
# 1346  1233228  180.0   137.2   -90.0
# 1347  1233228  200.0   137.3   -90.0
# 1348  1233228  220.0   137.4   -90.0
# 1349  1233228  230.0   137.4   -90.0
# 1350  1233229    0.0   135.0   -60.0
#
# [1351 rows x 4 columns]

# %% [markdown]
# Let's also calculate the downhole xyz from the depth, azimuth and dip values using the Minimum Curvature Method. It smooths two straight-line segments of the Balanced Tangential Method by using the Ratio Factor (RF = 2*tan(dl/2)/dl).
#
# <img src='./graphics/Minimum-Curvature-Method.jpg'>
#
# Where:
# MD = Measured Depth between surveys
# I1 = Inclination (angle) of upper survey in degrees
# I2 = Inclination (angle) of lower in degrees
# Az1= Azimuth direction of upper survey
# Az2 = Azimuth direction of lower survey
# RF = Ratio Factor
# ß  = the dog leg angle.
#
# Sources:
# http://www.drillingformulas.com/minimum-curvature-method/ <br>
# https://gis.stackexchange.com/questions/13484/how-to-convert-distance-azimuth-dip-to-xyz <br>
# http://www.cgg.com/data//1/rec_docs/2269_MinimumCurvatureWellPaths.pdf`<br>

# %%
dh2l.convert_survey(DB_Collar_Export,DB_Survey_Export, DB_Survey_Export_Calc)
dhsurvey_calc= pd.read_csv(DB_Survey_Export_Calc,encoding = "ISO-8859-1", dtype='object')
dhsurvey_calc.dropna()
dhsurvey_calc= dhsurvey_calc.loc[:, ~dhsurvey_calc.columns.str.contains('^Unnamed')]
print(dhsurvey_calc)
# Out:
#      CollarID       Depth     Azimuth         Dip Index              X  \
# 0      153802    0.000000   90.000000  -50.000000     2  495028.106029
# 1      153802    0.000000   90.000000  -50.000000     2  494917.618977
# 2      153803    0.000000   90.000000  -55.000000     4  495028.106029
# 3      153803    0.000000   90.000000  -55.000000     4  494906.041567
# 4      153804    0.000000   90.000000  -60.000000     6  495028.106029
# 5      153804    0.000000   90.000000  -60.000000     6  494970.810249
# 6      153804   60.000000   90.000000  -90.000000     6  494910.810249
# 7      153813    0.000000   90.000000  -60.000000     9  495028.139397
# 8      153813    0.000000   90.000000  -60.000000     9  494980.392914
# 9      153813   50.000000   90.000000  -90.000000     9  494930.392914
# 10     153813  100.000000   90.000000  -90.000000     9  494856.392914
# 11     153816    0.000000   90.000000  -60.000000    13  495028.153698
# 12     153816    0.000000   90.000000  -60.000000    13  494980.407215
# 13     153816   50.000000   90.000000  -90.000000    13  494930.407215
# 0     6802449.793954  390.166000
# 1     6802449.793954  349.952002
# 2     6802449.793954  359.251000
# 3     6802449.793954  320.764223
# 4     6802449.793954  359.132000
# 5     6802449.793954  343.779642
# 6     6802449.793954  343.779642
# 7     6802372.241019  359.122000
# 8     6802372.241019  346.328368
# 9     6802372.241019  346.328368
# 10    6802372.241019  346.328368
# 11    6802339.004044  359.387000
# 12    6802339.004044  346.593368
# 13    6802339.004044  346.593368
# 14    6802339.004044  346.593368
# 15    6802571.662836  359.737000
# 16    6802571.662836  345.919878
# 17    6802571.662836  345.919878
# 18    6802571.662836  345.919878
# 19    6802638.136763  358.549000
# 20    6802638.136763  345.755368
# 21    6802638.136763  345.755368
# 22    6802638.136763  345.755368
# 23    6747200.116329  358.533000
# 24    6747200.125405  353.544284
# 25    6747200.736118  353.544284
# 26    6747202.148593  353.544284
# 27    6747204.082851  353.544284
# 28    6747206.312219  353.544284
# 29    6747208.610961  353.544284
# ...              ...         ...
# 1320  6775573.050571  360.372955
# 1321  6775585.852759  360.372955
# 1322  6775598.601232  360.372955
# 1323  6775748.152255  376.292000
# 1324  6775761.824419  370.889141
# 1325  6775776.522345  370.889141
# 1326  6775791.581582  370.889141
# 1327  6775807.263258  370.889141
# 1328  6775823.742761  370.889141
# 1329  6775840.525568  370.889141
# 1330  6775857.193592  370.889141
# 1331  6775873.803563  370.889141
# 1332  6775890.471537  370.889141
# 1333  6775907.071370  370.889141
# 1334  6775923.534097  370.889141
# 1335  6775939.996824  370.889141
# 1336  6775948.208300  370.889141
# 1337  6775537.643372  370.619000
# 1338  6775551.493685  364.772524
# 1339  6775566.180118  364.772524
# 1340  6775580.913866  364.772524
# 1341  6775595.647614  364.772524
# 1342  6775610.369556  364.772524
# 1343  6775625.091498  364.772524
# 1344  6775639.813439  364.772524
# 1345  6775654.582516  364.772524
# 1346  6775669.327996  364.772524
# 1347  6775684.014444  364.772524
# 1348  6775698.724565  364.772524
# 1349  6775706.085535  364.772524
#
# [1350 rows x 8 columns]

# %% [markdown]
# The survey data export includes the following data:
#     1. CollarID
#     2. Depth
#     3. Azimuth
#     4. Dip
#     5. X
#     6. Y
#     7. Z

# %% [markdown]
# ## Exporting Lithology Data

# %% [markdown]
# Again, we have a pair of tables: <b> dhgeology </b> and <b> dhgeologyattr</b>.

# %%
dhgeology= pd.read_csv(dhgeology_file,encoding = "ISO-8859-1", dtype='object')
dhgeology.head()
# Out:
#         id collarid fromdepth todepth units accuracy modifieddate modifiedby  \
# 0  2537823   153803        59      61   NaN      NaN          NaN        NaN
# 1  2537824   153803        61      62   NaN      NaN          NaN        NaN
# 2  2537825   153803        62      69   NaN      NaN          NaN        NaN
# 3  2537826   153803        69      72   NaN      NaN          NaN        NaN
# 4  2537827   153803        72      73   NaN      NaN          NaN        NaN
#
#   mrtfileid
# 0      5255
# 1      5255
# 2      5255
# 3      5255
# 4      5255

# %%
dhgeologyattr= pd.read_csv(dhgeologyattr_file,encoding = "ISO-8859-1", dtype='object')
dhgeologyattr.head()
# Out:
#          id dhgeologyid       attributecolumn attributevalue modifieddate  \
# 0  20532422     2537765  Weathering_Intensity             ew          NaN
# 1  20532423     2537765              Regolith             Lf          NaN
# 2  20532424     2537765            Lithology1           Czlu          NaN
# 3  20532425     2537765            Grain_Size            vfg          NaN
# 4  20532426     2537765                Colour           bnrd          NaN
#
#   modifiedby mrtdetailid
# 0        NaN      116894
# 1        NaN      116895
# 2        NaN      116896
# 3        NaN      116898
# 4        NaN      116899

# %%
dh2l.litho_attr_val_dic(dic_attr_val_lithology_file)
dh2l.litho_dico (litho_dic_file)
dh2l.clean_up (cleanup_lithology_file)
dh2l.litho_attr_val_with_fuzzy (CET_Litho)

# %%
dh2l.litho_final (collar_file, dhgeology_file, dhgeologyattr_file, dic_attr_col_lithology_file, CET_Litho, DB_Lithology_Export)

# %% [markdown]
# Exporting lithology is a bit more tricky than collar and survey because what we get are rock codes (i.e., BAS, GRA) that have to be further decoded.
# Let's breakdown the steps done in the export.
#
# <img src='./graphics/lithology_thesauri.png'>
#
# First, the Company_LithoCodes are pulled out the same way we did for Collar and Survey. We use a <b> Litho thesaurus (Thesuarus 1) </b> that lists all the attribute columns that refer to lithology.

# %%
dic_att_col_lithology=pd.read_csv(dic_attr_col_lithology_file,encoding = "ISO-8859-1", dtype='object')
print(dic_att_col_lithology)
# Out:
#      attributecolumn
# 0       lithological
# 1       lihological
# 2                LIT
# 3               LITH
# 4               Lith
# 5             Lith_1
# 6             LITH_1
# 7        Lith_1_Code
# 8          Lith_code
# 9          lith_code
# 10         Lith_Code
# 11        lith_code1
# 12        Lith_Code1
# 13    Lith_Qualifier
# 14  Lith_Quallifier1
# 15             Lith1
# 16             LITH1
# 17         Lith1_100
# 18         Lith1_101
# 19         Lith1_Cat
# 20        LITH1_CODE
# 21        lith1_code
# 22        Lith1_code
# 23        Lith1_Code
# 24         Lith1Code
# 25         LITHOLOGY
# 26         lithology
# 27         Lithology
# 28      LITHOLOGY  1
# 29       Lithology 1
# 30       Lithology_1
# 31        LITHOLOGY1
# 32        Lithology1
# 33    Main Geol Unit
# 34    Maj. Lithology
# 35        Major Rock
# 36              RCK1
# 37              rck1
# 38              Rock
# 39              ROCK
# 40            Rock 1
# 41             Rock1
# 42             ROCK1
# 43             rock1
# 44          ROCKCODE
# 45          Rockcode
# 46         RockMajor
# 47         wmc_lith1

# %% [markdown]
# The <b> second thesaurus (from logging protocols) </b> decodes the Company_Litho for the corresponding Company_LithoCode.

# %%
dic_attr_val_lithology=pd.read_csv(dic_attr_val_lithology_file,encoding = "ISO-8859-1", dtype='object')
dic_attr_val_lithology.head()
# Out:
#   company_id company_code              comapany_litho
# 0      11410           GR                     Granite
# 1      11410           MG                      Gabbro
# 2      11410           SA    Undifferentiated arenite
# 3      11410           CL                        Clay
# 4      12411           Gr  Granitiod undifferentiated

# %% [markdown]
# Before performing the fuzzywuzzy matching, the Company_Litho text is cleaned to remove extra symbols and descriptions. This <b> cleanup_dictionary </b> includes mineral names, ages and qualifiers (i.e, dominant, abundant, minor).

# %%
cleanup_lithology=pd.read_csv(cleanup_lithology_file,encoding = "ISO-8859-1", dtype='object')
print(cleanup_lithology)
# Out:
#              clean
# 0         abundant
# 1       actinolite
# 2       adcumulate
# 3         adjacent
# 4         adularia
# 5         aegirine
# 6            agate
# 7           albite
# 8         alkaline
# 9         allanite
# 10       almandine
# 11         alunite
# 12       amorphous
# 13       amphibole
# 14    amygdaloidal
# 15        analcime
# 16         ancient
# 17      andalusite
# 18       andradite
# 19       anglesite
# 20         angular
# 21           angle
# 22       anhydrite
# 23        ankerite
# 24       anorthite
# 25   anthophyllite
# 26      anticlinal
# 27       anticline
# 28      antigorite
# 29        antimony
# ..             ...
# 552    vermiculite
# 553       vertical
# 554           very
# 555        vesicle
# 556    vesuvianite
# 557      violarite
# 558         violet
# 559             w.
# 560           wall
# 561           wash
# 562         weakly
# 563           weak
# 564      weathered
# 565           west
# 566            wet
# 567          white
# 568      willemite
# 569      witherite
# 570           with
# 571     wolframite
# 572   wollastonite
# 573     xenolithic
# 574      xenolitic
# 575       xenotime
# 576         yellow
# 577        younger
# 578        zeolite
# 579           zinc
# 580         zircon
# 581        zoisite
#
# [582 rows x 1 columns]

# %% [markdown]
# We use the fuzzywuzzy algorithm to standardize the lithologies. The FuzzyWuzzy matching compares the <b> Company_Litho </b> phrase against a <b> lithology thesaurus </b>. FuzzyWuzzy is a library of Python which is used for string matching. Fuzzy string matching is the process of finding strings that match a given pattern. It uses the Levenshtein Distance to calculate the differences between sequences.

# %% [markdown]
# Let's take a look at the <b> Lithology Thesaurus (Thesaurus 3) </b>. Each row refers to one entry. Each synonym is separated by a space.

# %%
lithology_thesaurus=pd.read_csv(litho_dic_file,encoding = "ISO-8859-1", dtype='object')
lithology_thesaurus[lithology_thesaurus['clean'].str.contains('Banded_iron_formation')]
# Out:
#                                                  clean
# 244  Banded_iron_formation iron-formationBIF Banded...

# %% [markdown]
# The processor we used to do the matching is: <b>fuzz.token_set_ratio </b>. It tokenize strings, but split the tokens into groups: intersection and remainder before comparing. It is not as strict as a using an exact processor but stricter than a partial match. Having a comprehensive thesaurus allows us this processor to work effectively. For more information on this: https://www.geeksforgeeks.org/fuzzywuzzy-python-library/
#
# Here's the pseudocode:<br>
# &emsp; scores=process.extract(Cleaned_Company_Litho, Litho_Dico, scorer=fuzz.token_set_ratio)<br>
# &emsp; &emsp; for sc in scores:
# &emsp; &emsp; &emsp; if(sc[score]>bestmatch): #better than previous best match<br>
# &emsp; &emsp; &emsp; &emsp; bestmatch =  sc[score]<br>
# &emsp; &emsp; &emsp; &emsp; bestlitho= Litho_Dico[firstword]<br>
# &emsp; &emsp; &emsp; &emsp; if(sc[litho]==Cleaned_Company_Litho[last]): #bonus for being last word in phrase<br>
# &emsp; &emsp; &emsp; &emsp; bestmatch=bestmatch*1.01<br>
# &emsp; &emsp; &emsp; elif (sc[score]==bestmatch): #equal to previous best match<br>
# &emsp; &emsp; &emsp; &emsp; if(sc[0]==words[last]): #bonus for being last word in phrase<br>
# &emsp; &emsp; &emsp; &emsp; &emsp; bestlitho=Litho_Dico[firstword]<br>
# &emsp; &emsp; &emsp; &emsp; &emsp; bestmatch=bestmatch*1.01<br>
# <br>
#
# The pseudocode shows that we input the <b> cleaned Company_Litho </b> and we parse it through a <b> lithology thesaurus </b>. We take in the score for each iteration and if it is greater than the previous match, it stores the <b> score (bestmatch) </b> and the <b> first lithology (CET_Litho) </b> listed in the corresponding lithology thesaurus entry. A bonus is also added to the score if the cleaned Company_Litho's last word matches the thesaurus.
# <br>
# Furthermore, if the match is less than a threshold we set (in this case, 80). The <b> CET_Litho </b> is classified as "unclassified _rock".

# %% [markdown]
# Let's take a look at the results:

# %%
DB_Lithology_Export_View=pd.read_csv(DB_Lithology_Export,encoding = "ISO-8859-1", dtype='object')
print(DB_Lithology_Export_View)
# Out:
#       Company_ID CollarID FromDepth ToDepth Company_LithoCode  \
# 0           3050  1146526        23      31                 X
# 1           3050  1146526        23      31                 X
# 2           3050  1146526        23      31                 X
# 3           3050  1146526        23      31                 X
# 4           3050  1146526        23      31                 X
# 5           3050  1146526        23      31                 X
# 6           3050  1146526        23      31                 X
# 7           3050  1146526        23      31                 X
# 8           3050  1146526        23      31                 X
# 9           3050  1146526        23      31                 X
# 10          3050  1146526        23      31                 X
# 11          3050  1146526        23      31                 X
# 12          3050  1146526        31      32                 X
# 13          3050  1146526        31      32                 X
# 14          3050  1146526        31      32                 X
# 15          3050  1146526        31      32                 X
# 16          3050  1146526        31      32                 X
# 17          3050  1146526        31      32                 X
# 18          3050  1146526        31      32                 X
# 19          3050  1146526        31      32                 X
# 20          3050  1146526        31      32                 X
# 21          3050  1146526        31      32                 X
# 22          3050  1146526        31      32                 X
# 23          3050  1146526        31      32                 X
# 24          3050  1146526        32      38                 X
# 25          3050  1146526        32      38                 X
# 26          3050  1146526        32      38                 X
# 27          3050  1146526        32      38                 X
# 28          3050  1146526        32      38                 X
# 29          3050  1146526        32      38                 X
# ...          ...      ...       ...     ...               ...
# 78252       3050   931220     193.3   212.3               Sbl
# 78253       3050   931220     193.3   212.3               Sbl
# 78254       3050   931220     193.3   212.3               Sbl
# 78255       3050   931220     193.3   212.3               Sbl
# 78256       3050   931220     193.3   212.3               Sbl
# 78257       3050   931220     193.3   212.3               Sbl
# 78258       3050   931220     212.3   213.6               Ssh
# 78259       3050   931220     212.3   213.6               Ssh
# 78260       3050   931220     212.3   213.6               Ssh
# 78261       3050   931220     212.3   213.6               Ssh
# 78262       3050   931220     212.3   213.6               Ssh
# 78263       3050   931220     212.3   213.6               Ssh
# 78264       3050   931220     213.6   214.8               Sbl
# 78265       3050   931220     213.6   214.8               Sbl
# 78266       3050   931220     213.6   214.8               Sbl
# 78267       3050   931220     213.6   214.8               Sbl
# 78268       3050   931220     213.6   214.8               Sbl
# 78269       3050   931220     213.6   214.8               Sbl
# 78270       3050   931220     214.8  217.88                 $
# 78271       3050   931220     214.8  217.88                 $
# 78272       3050   931220     214.8  217.88                 $
# 78273       3050   931220     214.8  217.88                 $
# 78274       3050   931220     214.8  217.88                 $
# 78275       3050   931220     214.8  217.88                 $
# 78276       3050   931220    217.88   229.4                 $
# 78277       3050   931220    217.88   229.4                 $
# 78278       3050   931220    217.88   229.4                 $
# 78279       3050   931220    217.88   229.4                 $
# 78280       3050   931220    217.88   229.4                 $
# 78281       3050   931220    217.88   229.4                 $
#
#                 Company_Litho          CET_Litho Score Unnamed: 8
# 0      breccia origin unknown  unclassified_rock   101        NaN
# 1                unknown rock               rock   101        NaN
# 2      breccia origin unknown  unclassified_rock   101        NaN
# 3                unknown rock               rock   101        NaN
# 4      breccia origin unknown  unclassified_rock   101        NaN
# 5                unknown rock               rock   101        NaN
# 6      breccia origin unknown  unclassified_rock   101        NaN
# 7                unknown rock               rock   101        NaN
# 8      breccia origin unknown  unclassified_rock   101        NaN
# 9                unknown rock               rock   101        NaN
# 10     breccia origin unknown  unclassified_rock   101        NaN
# 11               unknown rock               rock   101        NaN
# 12     breccia origin unknown  unclassified_rock   101        NaN
# 13               unknown rock               rock   101        NaN
# 14     breccia origin unknown  unclassified_rock   101        NaN
# 15               unknown rock               rock   101        NaN
# 16     breccia origin unknown  unclassified_rock   101        NaN
# 17               unknown rock               rock   101        NaN
# 18     breccia origin unknown  unclassified_rock   101        NaN
# 19               unknown rock               rock   101        NaN
# 20     breccia origin unknown  unclassified_rock   101        NaN
# 21               unknown rock               rock   101        NaN
# 22     breccia origin unknown  unclassified_rock   101        NaN
# 23               unknown rock               rock   101        NaN
# 24     breccia origin unknown  unclassified_rock   101        NaN
# 25               unknown rock               rock   101        NaN
# 26     breccia origin unknown  unclassified_rock   101        NaN
# 27               unknown rock               rock   101        NaN
# 28     breccia origin unknown  unclassified_rock   101        NaN
# 29               unknown rock               rock   101        NaN
# ...                       ...                ...   ...        ...
# 78252               limestone          limestone   101        NaN
# 78253               limestone          limestone   101        NaN
# 78254               limestone          limestone   101        NaN
# 78255               limestone          limestone   101        NaN
# 78256               limestone          limestone   101        NaN
# 78257               limestone          limestone   101        NaN
# 78258                   shale           mudstone   101        NaN
# 78259                   shale           mudstone   101        NaN
# 78260                   shale           mudstone   101        NaN
# 78261                   shale           mudstone   101        NaN
# 78262                   shale           mudstone   101        NaN
# 78263                   shale           mudstone   101        NaN
# 78264               limestone          limestone   101        NaN
# 78265               limestone          limestone   101        NaN
# 78266               limestone          limestone   101        NaN
# 78267               limestone          limestone   101        NaN
# 78268               limestone          limestone   101        NaN
# 78269               limestone          limestone   101        NaN
# 78270      massive sulphides    massive_sulphide    91        NaN
# 78271      massive sulphides    massive_sulphide    91        NaN
# 78272      massive sulphides    massive_sulphide    91        NaN
# 78273      massive sulphides    massive_sulphide    91        NaN
# 78274      massive sulphides    massive_sulphide    91        NaN
# 78275      massive sulphides    massive_sulphide    91        NaN
# 78276      massive sulphides    massive_sulphide    91        NaN
# 78277      massive sulphides    massive_sulphide    91        NaN
# 78278      massive sulphides    massive_sulphide    91        NaN
# 78279      massive sulphides    massive_sulphide    91        NaN
# 78280      massive sulphides    massive_sulphide    91        NaN
# 78281      massive sulphides    massive_sulphide    91        NaN
#
# [78282 rows x 9 columns]

# %% [markdown]
# ## Upscaling Lithology Data

# %% [markdown]
# In order to link and upscale the drillhole information, a <b> hierarchical thesaurus (Thesaurus 4) </b> was also built. The dictionary involved three levels that would upscale a list of 757 rock names to more general rock groups.

# %%
CET_hierarchy_dico = pd.read_csv(CET_hierarchy_dico_file,encoding = "ISO-8859-1")

# %%
dh2l.upscale_litho (DB_Lithology_Export, CET_hierarchy_dico_file, DB_Lithology_Upscaled)
Upscaled_Litho= pd.read_csv(DB_Lithology_Upscaled,encoding = "ISO-8859-1")
Upscaled_Litho.head()
# Out:
#    Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 0           0        3050   1146526       23.0     31.0                 X
# 1           1        3050   1146526       23.0     31.0                 X
# 2           2        3050   1146526       23.0     31.0                 X
# 3           3        3050   1146526       23.0     31.0                 X
# 4           4        3050   1146526       23.0     31.0                 X
#
#   Company_Litho CET_Litho  Score Level_3                     Level_2  \
# 0  unknown rock      rock    101    rock  natural_superficial_ground
# 1  unknown rock      rock    101    rock  natural_superficial_ground
# 2  unknown rock      rock    101    rock  natural_superficial_ground
# 3  unknown rock      rock    101    rock  natural_superficial_ground
# 4  unknown rock      rock    101    rock  natural_superficial_ground
#
#      Level_1
# 0  surficial
# 1  surficial
# 2  surficial
# 3  surficial
# 4  surficial

# %%
Upscaled_Litho[Upscaled_Litho['Level_1'] == "igneous"]
# Out:
#        Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 630           630        3050   1146526      352.8    356.1                As
# 631           631        3050   1146526      352.8    356.1                As
# 632           632        3050   1146526      352.8    356.1                As
# 633           633        3050   1146526      352.8    356.1                As
# 634           634        3050   1146526      352.8    356.1                As
# 635           635        3050   1146526      352.8    356.1                As
# 636           636        3050   1146530      193.3    197.7                As
# 637           637        3050   1146530      193.3    197.7                As
# 638           638        3050   1146530      193.3    197.7                As
# 639           639        3050   1146530      193.3    197.7                As
# 640           640        3050   1146530      193.3    197.7                As
# 641           641        3050   1146530      193.3    197.7                As
# 642           642        3050   1146526      352.8    356.1                As
# 643           643        3050   1146526      352.8    356.1                As
# 644           644        3050   1146526      352.8    356.1                As
# 645           645        3050   1146526      352.8    356.1                As
# 646           646        3050   1146526      352.8    356.1                As
# 647           647        3050   1146526      352.8    356.1                As
# 648           648        3050   1146530      193.3    197.7                As
# 649           649        3050   1146530      193.3    197.7                As
# 650           650        3050   1146530      193.3    197.7                As
# 651           651        3050   1146530      193.3    197.7                As
# 652           652        3050   1146530      193.3    197.7                As
# 653           653        3050   1146530      193.3    197.7                As
# 654           654        3050   1146526      352.8    356.1                As
# 655           655        3050   1146526      352.8    356.1                As
# 656           656        3050   1146526      352.8    356.1                As
# 657           657        3050   1146526      352.8    356.1                As
# 658           658        3050   1146526      352.8    356.1                As
# 659           659        3050   1146526      352.8    356.1                As
# ...           ...         ...       ...        ...      ...               ...
# 70026       70026        3050    548917       94.0    103.0                Mg
# 70027       70027        3050    548917       94.0    103.0                Mg
# 70028       70028        3050    548917       94.0    103.0                Mg
# 70029       70029        3050    548917       94.0    103.0                Mg
# 70030       70030        3050    548917       94.0    103.0                Mg
# 70031       70031        3050    548917       94.0    103.0                Mg
# 70032       70032        3050    548917       94.0    103.0                Mg
# 70033       70033        3050    548917       94.0    103.0                Mg
# 70034       70034        3050    548917       94.0    103.0                Mg
# 70035       70035        3050    548917       94.0    103.0                Mg
# 70036       70036        3050    548917       94.0    103.0                Mg
# 70037       70037        3050    548917       94.0    103.0                Mg
# 70038       70038        3050    548917      200.0    204.0                 U
# 70039       70039        3050    548917      200.0    204.0                 U
# 70040       70040        3050    548917      200.0    204.0                 U
# 70041       70041        3050    548917      200.0    204.0                 U
# 70042       70042        3050    548917      200.0    204.0                 U
# 70043       70043        3050    548917      200.0    204.0                 U
# 70044       70044        3050    548917      200.0    204.0                 U
# 70045       70045        3050    548917      200.0    204.0                 U
# 70046       70046        3050    548917      200.0    204.0                 U
# 70047       70047        3050    548917      200.0    204.0                 U
# 70048       70048        3050    548917      200.0    204.0                 U
# 70049       70049        3050    548917      200.0    204.0                 U
# 70050       70050        3050    548917      200.0    204.0                 U
# 70051       70051        3050    548917      200.0    204.0                 U
# 70052       70052        3050    548917      200.0    204.0                 U
# 70053       70053        3050    548917      200.0    204.0                 U
# 70054       70054        3050    548917      200.0    204.0                 U
# 70055       70055        3050    548917      200.0    204.0                 U
#
#           Company_Litho        CET_Litho  Score          Level_3  \
# 630             syenite          syenite    101          syenite
# 631             syenite          syenite    101          syenite
# 632             syenite          syenite    101          syenite
# 633             syenite          syenite    101          syenite
# 634             syenite          syenite    101          syenite
# 635             syenite          syenite    101          syenite
# 636             syenite          syenite    101          syenite
# 637             syenite          syenite    101          syenite
# 638             syenite          syenite    101          syenite
# 639             syenite          syenite    101          syenite
# 640             syenite          syenite    101          syenite
# 641             syenite          syenite    101          syenite
# 642             syenite          syenite    101          syenite
# 643             syenite          syenite    101          syenite
# 644             syenite          syenite    101          syenite
# 645             syenite          syenite    101          syenite
# 646             syenite          syenite    101          syenite
# 647             syenite          syenite    101          syenite
# 648             syenite          syenite    101          syenite
# 649             syenite          syenite    101          syenite
# 650             syenite          syenite    101          syenite
# 651             syenite          syenite    101          syenite
# 652             syenite          syenite    101          syenite
# 653             syenite          syenite    101          syenite
# 654             syenite          syenite    101          syenite
# 655             syenite          syenite    101          syenite
# 656             syenite          syenite    101          syenite
# 657             syenite          syenite    101          syenite
# 658             syenite          syenite    101          syenite
# 659             syenite          syenite    101          syenite
# ...                 ...              ...    ...              ...
# 70026            gabbro           gabbro    101           gabbro
# 70027            gabbro           gabbro    101           gabbro
# 70028            gabbro           gabbro    101           gabbro
# 70029            gabbro           gabbro    101           gabbro
# 70030            gabbro           gabbro    101           gabbro
# 70031            gabbro           gabbro    101           gabbro
# 70032            gabbro           gabbro    101           gabbro
# 70033            gabbro           gabbro    101           gabbro
# 70034            gabbro           gabbro    101           gabbro
# 70035            gabbro           gabbro    101           gabbro
# 70036            gabbro           gabbro    101           gabbro
# 70037            gabbro           gabbro    101           gabbro
# 70038  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70039  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70040  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70041  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70042  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70043  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70044  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70045  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70046  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70047  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70048  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70049  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70050  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70051  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70052  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70053  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70054  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
# 70055  ultramafic rocks  ultramafic-rock     97  ultramafic-rock
#
#                                        Level_2  Level_1
# 630    intermediate_coarse-grained crystalline  igneous
# 631    intermediate_coarse-grained crystalline  igneous
# 632    intermediate_coarse-grained crystalline  igneous
# 633    intermediate_coarse-grained crystalline  igneous
# 634    intermediate_coarse-grained crystalline  igneous
# 635    intermediate_coarse-grained crystalline  igneous
# 636    intermediate_coarse-grained crystalline  igneous
# 637    intermediate_coarse-grained crystalline  igneous
# 638    intermediate_coarse-grained crystalline  igneous
# 639    intermediate_coarse-grained crystalline  igneous
# 640    intermediate_coarse-grained crystalline  igneous
# 641    intermediate_coarse-grained crystalline  igneous
# 642    intermediate_coarse-grained crystalline  igneous
# 643    intermediate_coarse-grained crystalline  igneous
# 644    intermediate_coarse-grained crystalline  igneous
# 645    intermediate_coarse-grained crystalline  igneous
# 646    intermediate_coarse-grained crystalline  igneous
# 647    intermediate_coarse-grained crystalline  igneous
# 648    intermediate_coarse-grained crystalline  igneous
# 649    intermediate_coarse-grained crystalline  igneous
# 650    intermediate_coarse-grained crystalline  igneous
# 651    intermediate_coarse-grained crystalline  igneous
# 652    intermediate_coarse-grained crystalline  igneous
# 653    intermediate_coarse-grained crystalline  igneous
# 654    intermediate_coarse-grained crystalline  igneous
# 655    intermediate_coarse-grained crystalline  igneous
# 656    intermediate_coarse-grained crystalline  igneous
# 657    intermediate_coarse-grained crystalline  igneous
# 658    intermediate_coarse-grained crystalline  igneous
# 659    intermediate_coarse-grained crystalline  igneous
# ...                                        ...      ...
# 70026         mafic_coarse-grained crystalline  igneous
# 70027         mafic_coarse-grained crystalline  igneous
# 70028         mafic_coarse-grained crystalline  igneous
# 70029         mafic_coarse-grained crystalline  igneous
# 70030         mafic_coarse-grained crystalline  igneous
# 70031         mafic_coarse-grained crystalline  igneous
# 70032         mafic_coarse-grained crystalline  igneous
# 70033         mafic_coarse-grained crystalline  igneous
# 70034         mafic_coarse-grained crystalline  igneous
# 70035         mafic_coarse-grained crystalline  igneous
# 70036         mafic_coarse-grained crystalline  igneous
# 70037         mafic_coarse-grained crystalline  igneous
# 70038                               ultramafic  igneous
# 70039                               ultramafic  igneous
# 70040                               ultramafic  igneous
# 70041                               ultramafic  igneous
# 70042                               ultramafic  igneous
# 70043                               ultramafic  igneous
# 70044                               ultramafic  igneous
# 70045                               ultramafic  igneous
# 70046                               ultramafic  igneous
# 70047                               ultramafic  igneous
# 70048                               ultramafic  igneous
# 70049                               ultramafic  igneous
# 70050                               ultramafic  igneous
# 70051                               ultramafic  igneous
# 70052                               ultramafic  igneous
# 70053                               ultramafic  igneous
# 70054                               ultramafic  igneous
# 70055                               ultramafic  igneous
#
# [3996 rows x 12 columns]

# %%
Upscaled_Litho[Upscaled_Litho['Level_2'] == "ore"]
# Out:
#        Unnamed: 0  Company_ID  CollarID  FromDepth  ToDepth Company_LithoCode  \
# 2934         2934        1621   1233095       0.00    12.00               Sif
# 2935         2935        1621   1233095       0.00    12.00               Sif
# 2936         2936        1621   1233095       0.00    12.00               Sif
# 2937         2937        1621   1233095       0.00    12.00               Sif
# 2938         2938        1621   1233095       0.00    12.00               Sif
# 2939         2939        1621   1233095       0.00    12.00               Sif
# 69618  granodiorite  granodiorite    101  granodiorite
# 69619  granodiorite  granodiorite    101  granodiorite
# 69620  granodiorite  granodiorite    101  granodiorite
# 69621  granodiorite  granodiorite    101  granodiorite
# 69622  granodiorite  granodiorite    101  granodiorite
# 69623  granodiorite  granodiorite    101  granodiorite
# 69624  granodiorite  granodiorite    101  granodiorite
# 69625  granodiorite  granodiorite    101  granodiorite
# 69626  granodiorite  granodiorite    101  granodiorite
# 69627  granodiorite  granodiorite    101  granodiorite
# 69628  granodiorite  granodiorite    101  granodiorite
# 69629  granodiorite  granodiorite    101  granodiorite
# 69630  granodiorite  granodiorite    101  granodiorite
# 69631  granodiorite  granodiorite    101  granodiorite
# 69632  granodiorite  granodiorite    101  granodiorite
# 69633  granodiorite  granodiorite    101  granodiorite
# 69634  granodiorite  granodiorite    101  granodiorite
# 69635  granodiorite  granodiorite    101  granodiorite
# ...             ...           ...    ...           ...
# 69954  granodiorite  granodiorite    101  granodiorite
# 69955  granodiorite  granodiorite    101  granodiorite
# 69956  granodiorite  granodiorite    101  granodiorite
# 69957  granodiorite  granodiorite    101  granodiorite
# 69958  granodiorite  granodiorite    101  granodiorite
# 69959  granodiorite  granodiorite    101  granodiorite
# 69960  granodiorite  granodiorite    101  granodiorite
# 69961  granodiorite  granodiorite    101  granodiorite
# 69962  granodiorite  granodiorite    101  granodiorite
# 69963  granodiorite  granodiorite    101  granodiorite
# 69964  granodiorite  granodiorite    101  granodiorite
# 69965  granodiorite  granodiorite    101  granodiorite
# 69966  granodiorite  granodiorite    101  granodiorite
# 69967  granodiorite  granodiorite    101  granodiorite
# 69968  granodiorite  granodiorite    101  granodiorite
# 69969  granodiorite  granodiorite    101  granodiorite
# 69970  granodiorite  granodiorite    101  granodiorite
# 69971  granodiorite  granodiorite    101  granodiorite
# 69972  granodiorite  granodiorite    101  granodiorite
# 69973  granodiorite  granodiorite    101  granodiorite
# 69974  granodiorite  granodiorite    101  granodiorite
# 69975  granodiorite  granodiorite    101  granodiorite
# 69976  granodiorite  granodiorite    101  granodiorite
# 69977  granodiorite  granodiorite    101  granodiorite
# 69978  granodiorite  granodiorite    101  granodiorite
# 69979  granodiorite  granodiorite    101  granodiorite
# 69980  granodiorite  granodiorite    101  granodiorite
# 69981  granodiorite  granodiorite    101  granodiorite
# 69982  granodiorite  granodiorite    101  granodiorite
# 69983  granodiorite  granodiorite    101  granodiorite
#
#                                  Level_2  Level_1
# 69606  felsic_coarse-grained crystalline  igneous
# 69607  felsic_coarse-grained crystalline  igneous
# 69608  felsic_coarse-grained crystalline  igneous
# 69609  felsic_coarse-grained crystalline  igneous
# 69610  felsic_coarse-grained crystalline  igneous
# 69611  felsic_coarse-grained crystalline  igneous
# 69612  felsic_coarse-grained crystalline  igneous
# 69613  felsic_coarse-grained crystalline  igneous
# 69614  felsic_coarse-grained crystalline  igneous
# 69615  felsic_coarse-grained crystalline  igneous
# 69616  felsic_coarse-grained crystalline  igneous
# 69617  felsic_coarse-grained crystalline  igneous
# 69618  felsic_coarse-grained crystalline  igneous
# 69619  felsic_coarse-grained crystalline  igneous
# 69620  felsic_coarse-grained crystalline  igneous
# 69621  felsic_coarse-grained crystalline  igneous
# 69622  felsic_coarse-grained crystalline  igneous
# 69623  felsic_coarse-grained crystalline  igneous
# 69624  felsic_coarse-grained crystalline  igneous
# 69625  felsic_coarse-grained crystalline  igneous
# 69626  felsic_coarse-grained crystalline  igneous
# 69627  felsic_coarse-grained crystalline  igneous
# 69628  felsic_coarse-grained crystalline  igneous
# 69629  felsic_coarse-grained crystalline  igneous
# 69630  felsic_coarse-grained crystalline  igneous
# 69631  felsic_coarse-grained crystalline  igneous
# 69632  felsic_coarse-grained crystalline  igneous
# 69633  felsic_coarse-grained crystalline  igneous
# 69634  felsic_coarse-grained crystalline  igneous
# 69635  felsic_coarse-grained crystalline  igneous
# ...                                  ...      ...
# 69954  felsic_coarse-grained crystalline  igneous
# 69955  felsic_coarse-grained crystalline  igneous
# 69956  felsic_coarse-grained crystalline  igneous
# 69957  felsic_coarse-grained crystalline  igneous
# 69958  felsic_coarse-grained crystalline  igneous
# 69959  felsic_coarse-grained crystalline  igneous
# 69960  felsic_coarse-grained crystalline  igneous
# 69961  felsic_coarse-grained crystalline  igneous
# 69962  felsic_coarse-grained crystalline  igneous
# 69963  felsic_coarse-grained crystalline  igneous
# 69964  felsic_coarse-grained crystalline  igneous
# 69965  felsic_coarse-grained crystalline  igneous
# 69966  felsic_coarse-grained crystalline  igneous
# 69967  felsic_coarse-grained crystalline  igneous
# 69968  felsic_coarse-grained crystalline  igneous
# 69969  felsic_coarse-grained crystalline  igneous
# 69970  felsic_coarse-grained crystalline  igneous
# 69971  felsic_coarse-grained crystalline  igneous
# 69972  felsic_coarse-grained crystalline  igneous
# 69973  felsic_coarse-grained crystalline  igneous
# 69974  felsic_coarse-grained crystalline  igneous
# 69975  felsic_coarse-grained crystalline  igneous
# 69976  felsic_coarse-grained crystalline  igneous
# 69977  felsic_coarse-grained crystalline  igneous
# 69978  felsic_coarse-grained crystalline  igneous
# 69979  felsic_coarse-grained crystalline  igneous
# 69980  felsic_coarse-grained crystalline  igneous
# 69981  felsic_coarse-grained crystalline  igneous
# 69982  felsic_coarse-grained crystalline  igneous
# 69983  felsic_coarse-grained crystalline  igneous
#
# [378 rows x 12 columns]

# %% [markdown]
# Let's also calculate for the X,Y,Z coordinates for FromDepth, ToDepth and its midpoint.

# %%
dh2l.convert_lithology(DB_Collar_Export, DB_Survey_Export, DB_Lithology_Upscaled, DB_Lithology_Export_Calc)
DB_Lithology_Export_Calculated=pd.read_csv(DB_Lithology_Export_Calc)
print(DB_Lithology_Export_Calculated)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company_ID, CollarID, FromDepth, ToDepth, Company_LithoCode, Company_Litho, CET_Litho, Score, Level_3, Level_2, Level_1, xbt, ybt, zbt, xmt, ymt, zmt, xet, yet, zet, Unnamed: 20]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Export to VTK

# %%
dh2l.intervals2vtk(DB_Lithology_Export_Calc, DB_Lithology_Export_VTK)

# %% [markdown]
# <img src='./graphics/vtk.png'>

# %% [markdown]
# Open Paraview to view the VTK files and have some fun!<br>
# The VTK file output is at \dh2loop\data\export\DB_Lithology_Export.vtp
